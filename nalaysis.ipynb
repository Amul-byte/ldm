# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/diffusion_1000step_march14/tables/stage2_latest_epoch_metrics.csv')

# %%
df.columns
# Out:
# Index(['epoch', 'epoch_time_sec', 'train_loss_align', 'val_loss_align'], dtype='object')

# %%
df[['val_loss_align', 'train_loss_align']].plot()
# Out:
# <Axes: >

# %%
df.drop(0,inplace=True)

# %%
df[['val_loss_align', 'train_loss_align']].plot()
# Out:
# <Axes: >

# %%
# !python generate.py \
  --stage1_ckpt outputs/retrain_meeting/checkpoints/stage1_best.pt \
  --stage2_ckpt outputs/retrain_meeting/checkpoints/stage2_best.pt \
  --stage3_ckpt outputs/retrain_meeting/checkpoints/stage3_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/retrain_meeting/gait_cache_v2_9metrics \
  --batch_size 32\
  --window 30 \
  --stride 15\
  --gait_metrics_dim 9 \
  --timesteps 500 \
  --sample_steps 100 \
  --target_class A08 \
  --max_attempts 64 \
  --save_gif \
  --gif_dir outputs/results4 \
  --gif_prefix recent_stage3_A08 \
  --classify
# Out:
# 2026-03-17 17:58:18.769182: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage2_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage3_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped invalid paired sample: S30A02T01.csv
# [dataset] Skipped invalid paired sample: S30A02T02.csv
# [dataset] Skipped invalid paired sample: S30A02T03.csv
# [dataset] Skipped invalid paired sample: S30A02T04.csv
# [dataset] Skipped invalid paired sample: S30A02T05.csv
# [dataset] Skipped invalid paired sample: S30A03T01.csv
# [dataset] Skipped invalid paired sample: S30A03T02.csv
# [dataset] Skipped invalid paired sample: S30A03T03.csv
# [dataset] Skipped invalid paired sample: S30A03T04.csv
# [dataset] Skipped invalid paired sample: S30A03T05.csv
# [dataset] Skipped invalid paired sample: S30A05T05.csv
# [dataset] Skipped invalid paired sample: S30A06T01.csv
# [dataset] Skipped invalid paired sample: S30A06T02.csv
# [dataset] Skipped invalid paired sample: S30A06T03.csv
# [dataset] Skipped invalid paired sample: S30A06T04.csv
# [dataset] Skipped invalid paired sample: S30A06T05.csv
# [dataset] Skipped invalid paired sample: S30A08T01.csv
# [dataset] Skipped invalid paired sample: S30A08T02.csv
# [dataset] Skipped invalid paired sample: S30A08T03.csv
# [dataset] Skipped invalid paired sample: S30A08T04.csv
# [dataset] Skipped invalid paired sample: S30A08T05.csv
# [dataset] Skipped invalid paired sample: S30A09T05.csv
# [dataset] Skipped invalid paired sample: S30A10T01.csv
# [dataset] Skipped invalid paired sample: S30A10T02.csv
# [dataset] Skipped invalid paired sample: S30A10T03.csv
# [dataset] Skipped invalid paired sample: S30A10T04.csv
# [dataset] Skipped invalid paired sample: S30A10T05.csv
# [dataset] Skipped invalid paired sample: S30A11T01.csv
# [dataset] Skipped invalid paired sample: S30A11T02.csv
# [dataset] Skipped invalid paired sample: S30A11T03.csv
# [dataset] Skipped invalid paired sample: S30A11T04.csv
# [dataset] Skipped invalid paired sample: S30A11T05.csv
# [dataset] Skipped invalid paired sample: S30A12T01.csv
# [dataset] Skipped invalid paired sample: S30A12T02.csv
# [dataset] Skipped invalid paired sample: S30A12T03.csv
# [dataset] Skipped invalid paired sample: S30A12T04.csv
# [dataset] Skipped invalid paired sample: S30A12T05.csv
# [dataset] Skipped invalid paired sample: S30A13T01.csv
# [dataset] Skipped invalid paired sample: S30A13T02.csv
# [dataset] Skipped invalid paired sample: S30A13T03.csv
# [dataset] Skipped invalid paired sample: S30A13T04.csv
# [dataset] Skipped invalid paired sample: S30A13T05.csv
# [dataset] Skipped invalid paired sample: S30A14T01.csv
# [dataset] Skipped invalid paired sample: S30A14T02.csv
# [dataset] Skipped invalid paired sample: S30A14T03.csv
# [dataset] Skipped invalid paired sample: S30A14T04.csv
# [dataset] Skipped invalid paired sample: S30A14T05.csv
# [dataset] Skipped invalid paired sample: S32A03T01.csv
# [dataset] Skipped invalid paired sample: S32A03T02.csv
# [dataset] Skipped invalid paired sample: S32A03T03.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# [dataset] Skipped invalid paired sample: S32A05T01.csv
# [dataset] Skipped invalid paired sample: S32A05T02.csv
# [dataset] Skipped invalid paired sample: S32A05T03.csv
# [dataset] Skipped invalid paired sample: S32A05T04.csv
# [dataset] Skipped invalid paired sample: S32A05T05.csv
# [dataset] Skipped invalid paired sample: S32A06T03.csv
# [dataset] Skipped invalid paired sample: S32A07T01.csv
# [dataset] Skipped invalid paired sample: S32A07T02.csv
# [dataset] Skipped invalid paired sample: S32A07T03.csv
# [dataset] Skipped invalid paired sample: S32A07T04.csv
# [dataset] Skipped invalid paired sample: S32A07T05.csv
# [dataset] Skipped invalid paired sample: S32A09T01.csv
# [dataset] Skipped invalid paired sample: S32A09T02.csv
# [dataset] Skipped invalid paired sample: S32A09T03.csv
# [dataset] Skipped invalid paired sample: S32A09T04.csv
# [dataset] Skipped invalid paired sample: S32A09T05.csv
# [dataset] Skipped invalid paired sample: S32A10T01.csv
# [dataset] Skipped invalid paired sample: S32A10T02.csv
# [dataset] Skipped invalid paired sample: S32A10T03.csv
# [dataset] Skipped invalid paired sample: S32A10T04.csv
# [dataset] Skipped invalid paired sample: S32A10T05.csv
# [dataset] Skipped invalid paired sample: S32A11T01.csv
# [dataset] Skipped invalid paired sample: S32A11T02.csv
# [dataset] Skipped invalid paired sample: S32A11T03.csv
# [dataset] Skipped invalid paired sample: S32A11T04.csv
# [dataset] Skipped invalid paired sample: S32A11T05.csv
# [dataset] Skipped invalid paired sample: S32A12T01.csv
# [dataset] Skipped invalid paired sample: S32A12T02.csv
# [dataset] Skipped invalid paired sample: S32A12T03.csv
# [dataset] Skipped invalid paired sample: S32A12T04.csv
# [dataset] Skipped invalid paired sample: S32A12T05.csv
# [dataset] Skipped invalid paired sample: S32A13T01.csv
# [dataset] Skipped invalid paired sample: S32A13T02.csv
# [dataset] Skipped invalid paired sample: S32A13T03.csv
# [dataset] Skipped invalid paired sample: S32A13T04.csv
# [dataset] Skipped invalid paired sample: S32A13T05.csv
# [dataset] Skipped invalid paired sample: S32A14T03.csv
# [dataset] Skipped invalid paired sample: S34A02T01.csv
# [dataset] Skipped invalid paired sample: S34A02T02.csv
# [dataset] Skipped invalid paired sample: S34A02T03.csv
# [dataset] Skipped invalid paired sample: S34A02T04.csv
# [dataset] Skipped invalid paired sample: S34A02T05.csv
# [dataset] Skipped invalid paired sample: S34A05T01.csv
# [dataset] Skipped invalid paired sample: S34A05T02.csv
# [dataset] Skipped invalid paired sample: S34A05T03.csv
# [dataset] Skipped invalid paired sample: S34A05T04.csv
# [dataset] Skipped invalid paired sample: S34A05T05.csv
# [dataset] Skipped invalid paired sample: S34A06T04.csv
# [dataset] Skipped invalid paired sample: S34A07T01.csv
# [dataset] Skipped invalid paired sample: S34A07T02.csv
# [dataset] Skipped invalid paired sample: S34A07T03.csv
# [dataset] Skipped invalid paired sample: S34A07T04.csv
# [dataset] Skipped invalid paired sample: S34A07T05.csv
# [dataset] Skipped invalid paired sample: S34A08T01.csv
# [dataset] Skipped invalid paired sample: S34A09T01.csv
# [dataset] Skipped invalid paired sample: S34A09T02.csv
# [dataset] Skipped invalid paired sample: S34A09T03.csv
# [dataset] Skipped invalid paired sample: S34A09T04.csv
# [dataset] Skipped invalid paired sample: S34A09T05.csv
# [dataset] Skipped invalid paired sample: S34A10T01.csv
# [dataset] Skipped invalid paired sample: S34A10T02.csv
# [dataset] Skipped invalid paired sample: S34A10T03.csv
# [dataset] Skipped invalid paired sample: S34A10T04.csv
# [dataset] Skipped invalid paired sample: S34A10T05.csv
# [dataset] Skipped invalid paired sample: S34A12T01.csv
# [dataset] Skipped invalid paired sample: S34A12T02.csv
# [dataset] Skipped invalid paired sample: S34A12T03.csv
# [dataset] Skipped invalid paired sample: S34A12T04.csv
# [dataset] Skipped invalid paired sample: S34A12T05.csv
# [dataset] Skipped invalid paired sample: S34A13T01.csv
# [dataset] Skipped invalid paired sample: S34A13T02.csv
# [dataset] Skipped invalid paired sample: S34A13T03.csv
# [dataset] Skipped invalid paired sample: S34A13T04.csv
# [dataset] Skipped invalid paired sample: S34A13T05.csv
# [dataset] Skipped invalid paired sample: S34A14T04.csv
# [dataset] Skipped invalid paired sample: S35A05T01.csv
# [dataset] Skipped invalid paired sample: S35A05T02.csv
# [dataset] Skipped invalid paired sample: S35A05T03.csv
# [dataset] Skipped invalid paired sample: S35A05T04.csv
# [dataset] Skipped invalid paired sample: S35A05T05.csv
# [dataset] Skipped invalid paired sample: S35A06T01.csv
# [dataset] Skipped invalid paired sample: S35A06T02.csv
# [dataset] Skipped invalid paired sample: S35A06T03.csv
# [dataset] Skipped invalid paired sample: S35A06T04.csv
# [dataset] Skipped invalid paired sample: S35A06T05.csv
# [dataset] Skipped invalid paired sample: S35A07T01.csv
# [dataset] Skipped invalid paired sample: S35A07T02.csv
# [dataset] Skipped invalid paired sample: S35A07T03.csv
# [dataset] Skipped invalid paired sample: S35A07T04.csv
# [dataset] Skipped invalid paired sample: S35A07T05.csv
# [dataset] Skipped invalid paired sample: S35A09T01.csv
# [dataset] Skipped invalid paired sample: S35A09T02.csv
# [dataset] Skipped invalid paired sample: S35A09T03.csv
# [dataset] Skipped invalid paired sample: S35A09T04.csv
# [dataset] Skipped invalid paired sample: S35A09T05.csv
# [dataset] Skipped invalid paired sample: S35A10T03.csv
# [dataset] Skipped invalid paired sample: S36A02T01.csv
# [dataset] Skipped invalid paired sample: S36A02T02.csv
# [dataset] Skipped invalid paired sample: S36A02T03.csv
# [dataset] Skipped invalid paired sample: S36A02T04.csv
# [dataset] Skipped invalid paired sample: S36A02T05.csv
# [dataset] Skipped invalid paired sample: S36A03T01.csv
# [dataset] Skipped invalid paired sample: S36A05T02.csv
# [dataset] Skipped invalid paired sample: S36A05T03.csv
# [dataset] Skipped invalid paired sample: S38A03T03.csv
# [dataset] Skipped invalid paired sample: S38A07T05.csv
# [dataset] Skipped invalid paired sample: S38A13T02.csv
# [dataset] Skipped invalid paired sample: S38A14T05.csv
# [dataset] Skipped invalid paired sample: S48A14T04.csv
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
# [dataset] Skipped invalid paired sample: S62A12T03.csv
# conditioning sample class: id=7 name=A08
# target class: id=7 name=A08 | matched=True | attempts=1
# h_global shape: (1, 256)
# z0_gen shape: (1, 30, 32, 256)
# x_hat shape: (1, 30, 32, 3)
# predicted class for sample[0]: id=7 name=A08
# saved gif: outputs/results4/recent_stage3_A08_20260317_175858_idx00_A08.gif
# logits shape: (1, 14)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/training_reports/stage2_20260328_145840/stage2/history.csv")

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df["epoch"], df["train_loss_align"], color="black", label="train_loss_align")
ax.plot(df["epoch"], df["val_loss_align"],   color="purple", label="val_loss_align")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Stage-2 Loss Curves")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df.tail(5)
# Out:
#     epoch  train_loss_cls  train_loss_diff  train_loss_gait  \
# 95   96.0        2.560395         0.032823         0.020737
# 96   97.0        2.558523         0.034497         0.019498
# 97   98.0        2.559789         0.032932         0.019699
# 98   99.0        2.560348         0.030317         0.019826
# 99  100.0        2.559938         0.030974         0.020715
#
#     train_loss_motion  train_loss_total  val_loss_cls  val_loss_diff  \
# 95           0.040003          0.349602      2.517938       0.032802
# 96           0.051264          0.361112      2.522358       0.033353
# 97           0.044064          0.352673      2.520670       0.030104
# 98           0.034335          0.340514      2.511716       0.029745
# 99           0.039373          0.347056      2.514795       0.025458
#
#     val_loss_gait  val_loss_motion  val_loss_total
# 95       0.020251         0.051788        2.622779
# 96       0.019856         0.035029        2.610595
# 97       0.020617         0.049186        2.620577
# 98       0.020976         0.026996        2.589433
# 99       0.019865         0.022863        2.582981

# %%
df = pd.read_csv('/home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/training_reports/sucon_stage2_classwise_window/stage2/history.csv')

# %%
df['val_loss_total'].describe()
# Out:
# count    100.000000
# mean       4.014365
# std        0.228025
# min        3.746104
# 25%        3.838124
# 50%        3.953518
# 75%        4.126970
# max        4.964833
# Name: val_loss_total, dtype: float64

# %%
print('/home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/stage1_gcnn_stage_2_withCE_window/skeleton_vs_imu_umap.png')
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/stage1_gcnn_stage_2_withCE_window/skeleton_vs_imu_umap.png
