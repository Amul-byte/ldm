# %%
# !python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --epochs 10
# Out:
# 2026-03-07 17:13:42,386 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-07 17:13:42,386 | INFO | train | Run dir: checkpoints
# 2026-03-07 17:13:42,386 | INFO | train | Device: cuda
# 2026-03-07 17:13:42,386 | INFO | train | Config: stage=1 epochs=10 batch_size=16 lr=0.0001 window=90 stride=30 joints=32 latent_dim=256 timesteps=500 val_split=0.1
# 2026-03-07 17:13:42,386 | INFO | train | Data mode: csv-folders
# 2026-03-07 17:13:42,386 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-07 17:13:42,386 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-07 17:13:42,386 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# 2026-03-07 17:13:42,386 | INFO | train | gait_cache_dir=outputs/gait_cache
# 2026-03-07 17:13:42,386 | INFO | train | Gait metrics dim: 10
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/train.py:429: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-07 17:13:54,654 | INFO | train | Dataset: Subset samples=7066 batches_per_epoch=441 drop_last=True
# 2026-03-07 17:13:54,654 | INFO | train | Validation: samples=785 batches=50 drop_last=False
# 2026-03-07 17:15:46,798 | INFO | train | [Stage1] epoch=1/10 train_loss_diff=1.145743 val_loss_diff=0.775514 epoch_time=112.1s
# Saved checkpoint: checkpoints/stage1_best.pt
# 2026-03-07 17:15:46,932 | INFO | train | [Stage1] new best checkpoint: checkpoints/stage1_best.pt (epoch=1 monitor_loss=0.775514)
# 2026-03-07 17:17:38,281 | INFO | train | [Stage1] epoch=2/10 train_loss_diff=0.640422 val_loss_diff=0.542928 epoch_time=111.3s
# Saved checkpoint: checkpoints/stage1_best.pt
# 2026-03-07 17:17:38,412 | INFO | train | [Stage1] new best checkpoint: checkpoints/stage1_best.pt (epoch=2 monitor_loss=0.542928)
# 2026-03-07 17:19:29,930 | INFO | train | [Stage1] epoch=3/10 train_loss_diff=0.489768 val_loss_diff=0.436504 epoch_time=111.5s
# Saved checkpoint: checkpoints/stage1_best.pt
# 2026-03-07 17:19:30,060 | INFO | train | [Stage1] new best checkpoint: checkpoints/stage1_best.pt (epoch=3 monitor_loss=0.436504)
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/train.py", line 1153, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/train.py", line 1140, in main
#     train_stage1(args, device, distributed=distributed, local_rank=local_rank)
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/train.py", line 456, in train_stage1
#     out = model(x, gait_metrics=gait_metrics)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model.py", line 70, in forward
#     z0 = self.encoder(x, gait_metrics=gait_metrics)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/skeleton_model.py", line 63, in forward
#     z = g_block(z, adjacency=adjacency, edge_index=edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/graph_modules.py", line 94, in forward
#     y = self.graph_op(h, edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/graph_modules.py", line 63, in forward
#     y = self.gat(x_flat, repeated_edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch_geometric/nn/conv/gat_conv.py", line 347, in forward
#     edge_index, edge_attr = remove_self_loops(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch_geometric/utils/loop.py", line 115, in remove_self_loops
# ^C
# Exception ignored in atexit callback: <function dump_compile_times at 0x7fd1f69253a0>
# Traceback (most recent call last):
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/_dynamo/utils.py", line 399, in dump_compile_times
#     log.info(compile_times(repr="str", aggregate=True))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/_dynamo/utils.py", line 385, in compile_times
#     out += tabulate(rows, headers=("Function", "Runtimes (s)"))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/_dynamo/utils.py", line 148, in tabulate
#     import tabulate
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/tabulate/__init__.py", line 764, in <module>
#     _ansi_codes_bytes = re.compile(_ansi_escape_pat.encode("utf8"), re.VERBOSE)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/re/__init__.py", line 227, in compile
#     return _compile(pattern, flags)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/re/__init__.py", line 285, in _compile
#     if not _compiler.isstring(pattern):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/re/_compiler.py", line 570, in isstring
#     def isstring(obj):
#
# KeyboardInterrupt:

# %%
# !python train.py \
  --stage 2 \
  --stage1_ckpt checkpoints/stage1.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --epochs 10
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# !python train.py \
  --stage 3 \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
   --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --epochs 10
# Out:
# 2026-03-07 19:09:24,832 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-07 19:09:24,832 | INFO | train | Run dir: checkpoints
# 2026-03-07 19:09:24,832 | INFO | train | Device: cuda
# 2026-03-07 19:09:24,833 | INFO | train | Config: stage=3 epochs=10 batch_size=16 lr=0.0001 window=90 stride=30 joints=32 latent_dim=256 timesteps=500 val_split=0.1
# 2026-03-07 19:09:24,833 | INFO | train | Data mode: csv-folders
# 2026-03-07 19:09:24,833 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-07 19:09:24,833 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-07 19:09:24,833 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# 2026-03-07 19:09:24,833 | INFO | train | gait_cache_dir=outputs/gait_cache
# 2026-03-07 19:09:24,833 | INFO | train | Gait metrics dim: 10
# 2026-03-07 19:09:24,833 | INFO | train | Stage3 objective: gait_only=True lambda_gait=1.0 fps=30.0
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/train.py:652: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-07 19:09:37,096 | INFO | train | Dataset: Subset samples=7066 batches_per_epoch=441 drop_last=True
# 2026-03-07 19:09:37,096 | INFO | train | Validation: samples=785 batches=50 drop_last=False
# 2026-03-07 19:12:40,951 | INFO | train | [Stage3] epoch=1/10 train_loss_total=0.037613 train_loss_gait=0.037613 val_loss_total=0.014697 val_loss_gait=0.014697 epoch_time=183.9s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:12:41,073 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=1 monitor_loss=0.014697)
# 2026-03-07 19:15:45,238 | INFO | train | [Stage3] epoch=2/10 train_loss_total=0.012044 train_loss_gait=0.012044 val_loss_total=0.009184 val_loss_gait=0.009184 epoch_time=184.2s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:15:45,339 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=2 monitor_loss=0.009184)
# 2026-03-07 19:18:47,777 | INFO | train | [Stage3] epoch=3/10 train_loss_total=0.012567 train_loss_gait=0.012567 val_loss_total=0.010026 val_loss_gait=0.010026 epoch_time=182.4s
# 2026-03-07 19:21:51,833 | INFO | train | [Stage3] epoch=4/10 train_loss_total=0.009440 train_loss_gait=0.009440 val_loss_total=0.008028 val_loss_gait=0.008028 epoch_time=184.1s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:21:51,957 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=4 monitor_loss=0.008028)
# 2026-03-07 19:24:55,419 | INFO | train | [Stage3] epoch=5/10 train_loss_total=0.008446 train_loss_gait=0.008446 val_loss_total=0.008777 val_loss_gait=0.008777 epoch_time=183.5s
# 2026-03-07 19:27:58,728 | INFO | train | [Stage3] epoch=6/10 train_loss_total=0.008559 train_loss_gait=0.008559 val_loss_total=0.008433 val_loss_gait=0.008433 epoch_time=183.3s
# 2026-03-07 19:31:02,509 | INFO | train | [Stage3] epoch=7/10 train_loss_total=0.007710 train_loss_gait=0.007710 val_loss_total=0.007967 val_loss_gait=0.007967 epoch_time=183.8s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:31:02,655 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=7 monitor_loss=0.007967)
# 2026-03-07 19:34:06,452 | INFO | train | [Stage3] epoch=8/10 train_loss_total=0.008237 train_loss_gait=0.008237 val_loss_total=0.007596 val_loss_gait=0.007596 epoch_time=183.8s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:34:06,569 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=8 monitor_loss=0.007596)
# 2026-03-07 19:37:06,818 | INFO | train | [Stage3] epoch=9/10 train_loss_total=0.007257 train_loss_gait=0.007257 val_loss_total=0.007858 val_loss_gait=0.007858 epoch_time=180.2s
# 2026-03-07 19:40:07,248 | INFO | train | [Stage3] epoch=10/10 train_loss_total=0.006930 train_loss_gait=0.006930 val_loss_total=0.006201 val_loss_gait=0.006201 epoch_time=180.4s
# Saved checkpoint: checkpoints/stage3_best.pt
# 2026-03-07 19:40:07,386 | INFO | train | [Stage3] new best checkpoint: checkpoints/stage3_best.pt (epoch=10 monitor_loss=0.006201)
# Saved checkpoint: checkpoints/stage3.pt
# 2026-03-07 19:40:07,490 | INFO | train | [Stage3] saved checkpoint: checkpoints/stage3.pt

# %%
# !python generate.py \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
  --stage3_ckpt checkpoints/stage3.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_gif \
  --gif_dir outputs/results \
  --gif_prefix sample
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage3.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# h_global shape: (2, 256)
# z0_gen shape: (2, 90, 32, 256)
# x_hat shape: (2, 90, 32, 3)
# predicted class for sample[0]: id=8 name=A09
# predicted class for sample[1]: id=8 name=A09
# saved gif: outputs/results/sample_20260307_204142_idx00_A09.gif
# saved gif: outputs/results/sample_20260307_204142_idx01_A09.gif

# %%
# !python generate.py \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
  --stage3_ckpt checkpoints/stage3.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --target_class A11 \
  --max_attempts 64 \
  --save_gif \
  --gif_dir outputs/results \
  --gif_prefix stage3_gen
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage3.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# conditioning sample class: id=10 name=A11
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/generate.py", line 302, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/generate.py", line 263, in main
#     x_try, logits_try, z0_try, h_global_try = _sample_once()
#                                               ^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/generate.py", line 240, in _sample_once
#     z0_local = stage3.diffusion.p_sample_loop(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/diffusion.py", line 146, in p_sample_loop
#     z = self.p_sample(
#         ^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/diffusion.py", line 109, in p_sample
#     pred_noise = denoiser(zt, t, sensor_tokens=h_tokens, h_tokens=h_tokens, h_global=h_global, gait_metrics=gait_metrics)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/skeleton_model.py", line 175, in forward
#     x = g_block(x, adjacency=adjacency, edge_index=edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/graph_modules.py", line 94, in forward
#     y = self.graph_op(h, edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/graph_modules.py", line 63, in forward
#     y = self.gat(x_flat, repeated_edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch_geometric/nn/conv/gat_conv.py", line 347, in forward
#     edge_index, edge_attr = remove_self_loops(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch_geometric/utils/loop.py", line 115, in remove_self_loops
#     if not torch.jit.is_scripting() and isinstance(edge_index, EdgeIndex):
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/_jit_internal.py", line 103, in is_scripting
#     def is_scripting() -> bool:
#
# KeyboardInterrupt
# ^C

# %%
# !python inspect_attention.py \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
  --stage3_ckpt checkpoints/stage3.pt \
 --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --out_dir outputs/attention
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/inspect_attention.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# loaded: checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# loaded: checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# loaded: checkpoints/stage3.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/inspect_attention.py:71: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(np.uint8(norm * 255.0), mode="L")
# saved cross block 0: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)
# saved cross block 1: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)
# saved cross block 2: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)
# saved cross block 3: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)
# saved cross block 4: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)
# saved cross block 5: raw=(2880, 90) frame_to_sensor=(90, 90) joints=(32,)

# %%
c = "/home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/attention"
print(c)
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/attention

# %%
import pandas as pd
df = pd.read_csv("/home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/new_1/tables/run_config_inventory.csv")
df
# Out:
#    batch_size    data_mode  dataset_path  epochs  \
# 0          16  csv-folders           NaN      50
# 1          16  csv-folders           NaN      50
# 2          16  csv-folders           NaN      50
#
#                                    gait_cache_dir  gait_metrics_dim  \
# 0  outputs/retrain_meeting/gait_cache_v2_9metrics                 9
# 1  outputs/retrain_meeting/gait_cache_v2_9metrics                 9
# 2  outputs/retrain_meeting/gait_cache_v2_9metrics                 9
#
#                                           hip_folder  joints  latent_dim  \
# 0  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      32         256
# 1  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      32         256
# 2  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      32         256
#
#        lr                              run_dir  \
# 0  0.0001  outputs/retrain_meeting/checkpoints
# 1  0.0001  outputs/retrain_meeting/checkpoints
# 2  0.0001  outputs/retrain_meeting/checkpoints
#
#                                      skeleton_folder  stage  stride  \
# 0  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      1      30
# 1  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      2      30
# 2  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...      3      30
#
#                  timestamp  timesteps  val_split  \
# 0  2026-03-08 22:08:14,902        500        0.1
# 1  2026-03-09 00:45:25,766        500        0.1
# 2  2026-03-09 01:04:39,172        500        0.1
#
#                                validation  window  \
# 0  samples=785 batches=50 drop_last=False      90
# 1  samples=785 batches=50 drop_last=False      90
# 2  samples=785 batches=50 drop_last=False      90
#
#                                         wrist_folder
# 0  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...
# 1  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...
# 2  /home/qsw26/smartfall/gait_loss/SmartFallMM-Da...
