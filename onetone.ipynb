# %%
# Stage 1
# !nohup python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --save_dir checkpoints \
  --report_dir outputs/training_reports \
  --run_name stage1_onetoone \
  --epochs 100 \
  --batch_size 4 \
  --lr 1e-4 \
  --window 90 \
  --stride 45 \
  --one_to_one \
  --train_subjects 28,29,30,31,33,35,38,39,32,36,37,43,44,45,46,49,51,56,57,58,59,61,62
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# Stage 2
# !nohup python train.py \
  --stage 2 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --stage1_ckpt checkpoints/stage1_best.pt \
  --save_dir checkpoints \
  --report_dir outputs/training_reports \
  --run_name stage2_onetoone \
  --epochs 100 \
  --batch_size 4 \
  --lr 1e-4 \
  --window 90 \
  --stride 45 \
  --one_to_one \
  --train_subjects 28,29,30,31,33,35,38,39,32,36,37,43,44,45,46,49,51,56,57,58,59,61,62

# %%
# Stage 3
# !nohup python train.py \
  --stage 3 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --stage1_ckpt checkpoints/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --save_dir checkpoints \
  --report_dir outputs/training_reports \
  --run_name stage3_onetoone \
  --epochs 100 \
  --batch_size 4 \
  --lr 1e-4 \
  --window 90 \
  --stride 45 \
  --one_to_one \
 --train_subjects 28,29,30,31,33,35,38,39,32,36,37,43,44,45,46,49,51,56,57,58,59,61,62 \
  --lambda_pose 1.0 \
  --lambda_latent 0.5 \
  --lambda_vel 0.5 \
  --lambda-gait 0.2 \
  --lambda_motion 0.1 \
  --fps 30 \
  --sampler ddim \
  --sample_steps 50 \
  --sample_seed 0
# Out:
# ^C
