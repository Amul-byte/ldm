# %%
# Stage 1
python train.py --stage 1 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --save_dir checkpoints

# Stage 2
python train.py --stage 2 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --stage1_ckpt checkpoints/stage1.pt --save_dir checkpoints

# Stage 3
python train.py --stage 3 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --stage1_ckpt checkpoints/stage1.pt --stage2_ckpt checkpoints/stage2.pt --save_dir checkpoints

# Generate + classify + GIF
python generate.py \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
  --timesteps 50 \
  --batch_size 2 \
  --save_gif \
  --gif_dir outputs/gifs \
  --gif_prefix gait \
  --classify

# %%
# !python train.py \
  --stage 2 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 \
  --stride 45 \
  --batch_size 32 \
  --epochs 20
# Out:
# 2026-03-01 04:59:10,754 | INFO | train | Run dir: checkpoints
# 2026-03-01 04:59:10,755 | INFO | train | Device: cuda
# 2026-03-01 04:59:10,755 | INFO | train | Config: stage=1 epochs=20 batch_size=32 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# 2026-03-01 04:59:10,755 | INFO | train | Data mode: csv-folders
# 2026-03-01 04:59:10,755 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-01 04:59:10,755 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-01 04:59:10,755 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# 2026-03-01 04:59:24,013 | INFO | train | Dataset: CSVPairedGaitDataset samples=5446 batches_per_epoch=170 drop_last=True
# 2026-03-01 05:00:54,026 | INFO | train | [Stage1] epoch=1/20 loss_diff=14282.290224 epoch_time=90.0s
# 2026-03-01 05:02:24,972 | INFO | train | [Stage1] epoch=2/20 loss_diff=225.424393 epoch_time=90.9s
# 2026-03-01 05:03:56,190 | INFO | train | [Stage1] epoch=3/20 loss_diff=36.131676 epoch_time=91.2s
# 2026-03-01 05:05:27,434 | INFO | train | [Stage1] epoch=4/20 loss_diff=15.791071 epoch_time=91.2s
# 2026-03-01 05:06:58,697 | INFO | train | [Stage1] epoch=5/20 loss_diff=9.338116 epoch_time=91.3s
# 2026-03-01 05:08:29,948 | INFO | train | [Stage1] epoch=6/20 loss_diff=6.224075 epoch_time=91.3s
# 2026-03-01 05:10:01,178 | INFO | train | [Stage1] epoch=7/20 loss_diff=4.646252 epoch_time=91.2s
# 2026-03-01 05:11:32,439 | INFO | train | [Stage1] epoch=8/20 loss_diff=3.689564 epoch_time=91.3s
# 2026-03-01 05:13:03,670 | INFO | train | [Stage1] epoch=9/20 loss_diff=3.123810 epoch_time=91.2s
# 2026-03-01 05:14:34,898 | INFO | train | [Stage1] epoch=10/20 loss_diff=2.685169 epoch_time=91.2s
# 2026-03-01 05:16:06,119 | INFO | train | [Stage1] epoch=11/20 loss_diff=2.442006 epoch_time=91.2s
# 2026-03-01 05:17:37,316 | INFO | train | [Stage1] epoch=12/20 loss_diff=2.245076 epoch_time=91.2s
# 2026-03-01 05:19:08,517 | INFO | train | [Stage1] epoch=13/20 loss_diff=2.064106 epoch_time=91.2s
# 2026-03-01 05:20:39,720 | INFO | train | [Stage1] epoch=14/20 loss_diff=1.915779 epoch_time=91.2s
# 2026-03-01 05:22:10,921 | INFO | train | [Stage1] epoch=15/20 loss_diff=1.847287 epoch_time=91.2s
# 2026-03-01 05:23:42,154 | INFO | train | [Stage1] epoch=16/20 loss_diff=1.713262 epoch_time=91.2s
# 2026-03-01 05:25:13,385 | INFO | train | [Stage1] epoch=17/20 loss_diff=1.646001 epoch_time=91.2s
# 2026-03-01 05:26:44,598 | INFO | train | [Stage1] epoch=18/20 loss_diff=1.587250 epoch_time=91.2s
# 2026-03-01 05:28:15,813 | INFO | train | [Stage1] epoch=19/20 loss_diff=1.531551 epoch_time=91.2s
# 2026-03-01 05:29:47,020 | INFO | train | [Stage1] epoch=20/20 loss_diff=1.502173 epoch_time=91.2s
# Saved checkpoint: checkpoints/stage1.pt
# 2026-03-01 05:29:47,081 | INFO | train | [Stage1] saved checkpoint: checkpoints/stage1.pt

# %%
# 2) Train Stage 2 (use trained Stage 1 checkpoint)
# !python train.py \
  --stage 2 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 \
  --stride 45 \
  --batch_size 32 \
  --epochs 20 \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal
# Out:
# 2026-03-01 05:36:47,094 | INFO | train | Run dir: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal
# 2026-03-01 05:36:47,094 | INFO | train | Device: cuda
# 2026-03-01 05:36:47,094 | INFO | train | Config: stage=2 epochs=20 batch_size=32 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# 2026-03-01 05:36:47,094 | INFO | train | Data mode: csv-folders
# 2026-03-01 05:36:47,094 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-01 05:36:47,094 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-01 05:36:47,094 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# /home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# 2026-03-01 05:36:59,837 | INFO | train | Dataset: CSVPairedGaitDataset samples=5446 batches_per_epoch=170 drop_last=True
# 2026-03-01 05:37:16,960 | INFO | train | [Stage2] epoch=1/20 loss_align=910696.029779 epoch_time=17.1s
# 2026-03-01 05:37:33,468 | INFO | train | [Stage2] epoch=2/20 loss_align=759872.273529 epoch_time=16.5s
# 2026-03-01 05:37:49,906 | INFO | train | [Stage2] epoch=3/20 loss_align=511272.521875 epoch_time=16.4s
# 2026-03-01 05:38:06,341 | INFO | train | [Stage2] epoch=4/20 loss_align=294349.877941 epoch_time=16.4s
# 2026-03-01 05:38:22,807 | INFO | train | [Stage2] epoch=5/20 loss_align=173159.815119 epoch_time=16.5s
# 2026-03-01 05:38:40,616 | INFO | train | [Stage2] epoch=6/20 loss_align=126255.023851 epoch_time=17.8s
# 2026-03-01 05:38:57,654 | INFO | train | [Stage2] epoch=7/20 loss_align=112214.197243 epoch_time=17.0s
# 2026-03-01 05:39:14,412 | INFO | train | [Stage2] epoch=8/20 loss_align=106684.381066 epoch_time=16.8s
# 2026-03-01 05:39:31,141 | INFO | train | [Stage2] epoch=9/20 loss_align=104512.917279 epoch_time=16.7s
# 2026-03-01 05:39:47,833 | INFO | train | [Stage2] epoch=10/20 loss_align=103258.464476 epoch_time=16.7s
# 2026-03-01 05:40:04,386 | INFO | train | [Stage2] epoch=11/20 loss_align=102777.901838 epoch_time=16.6s
# 2026-03-01 05:40:21,281 | INFO | train | [Stage2] epoch=12/20 loss_align=102442.560501 epoch_time=16.9s
# 2026-03-01 05:40:37,712 | INFO | train | [Stage2] epoch=13/20 loss_align=102054.621186 epoch_time=16.4s
# 2026-03-01 05:40:54,241 | INFO | train | [Stage2] epoch=14/20 loss_align=101846.650092 epoch_time=16.5s
# 2026-03-01 05:41:10,835 | INFO | train | [Stage2] epoch=15/20 loss_align=101611.380561 epoch_time=16.6s
# 2026-03-01 05:41:27,470 | INFO | train | [Stage2] epoch=16/20 loss_align=101344.106480 epoch_time=16.6s
# 2026-03-01 05:41:44,039 | INFO | train | [Stage2] epoch=17/20 loss_align=101095.522426 epoch_time=16.6s
# 2026-03-01 05:42:00,566 | INFO | train | [Stage2] epoch=18/20 loss_align=100914.501195 epoch_time=16.5s
# 2026-03-01 05:42:17,126 | INFO | train | [Stage2] epoch=19/20 loss_align=100866.538143 epoch_time=16.6s
# 2026-03-01 05:42:33,745 | INFO | train | [Stage2] epoch=20/20 loss_align=100590.151838 epoch_time=16.6s
# Saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal/stage2.pt
# 2026-03-01 05:42:33,780 | INFO | train | [Stage2] saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal/stage2.pt

# %%
# # 3) Train Stage 3 (use Stage 1 + Stage 2 checkpoints)
# !nohup python train.py \
#   --stage 3 \
#   --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
#   --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
#   --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
#   --window 90 \
#   --stride 45 \
#   --batch_size 32 \
#   --epochs 20 \
#   --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
#   --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal/stage2.pt\
#   --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal

# %%
# !python train.py \
  --stage 3 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 \
  --stride 45 \
  --batch_size 4 \
  --epochs 20 \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
  --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt\
  --timesteps 500
# Out:
# 2026-03-01 22:21:41,020 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-01 22:21:41,020 | INFO | train | Run dir: checkpoints
# 2026-03-01 22:21:41,020 | INFO | train | Device: cuda
# 2026-03-01 22:21:41,020 | INFO | train | Config: stage=3 epochs=20 batch_size=4 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# 2026-03-01 22:21:41,020 | INFO | train | Data mode: csv-folders
# 2026-03-01 22:21:41,020 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-01 22:21:41,020 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-01 22:21:41,020 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# /home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# /home/qsw26/smartfall/gait_loss/ldm/train.py:503: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-01 22:21:53,901 | INFO | train | Dataset: CSVPairedGaitDataset samples=5446 batches_per_epoch=1361 drop_last=True
# 2026-03-01 22:24:00,100 | INFO | train | [Stage3] epoch=1/20 loss_total=nan loss_diff=nan loss_cls=nan epoch_time=126.2s
# 2026-03-01 22:26:05,302 | INFO | train | [Stage3] epoch=2/20 loss_total=nan loss_diff=nan loss_cls=nan epoch_time=125.2s
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 638, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 629, in main
#     train_stage3(args, device, distributed=distributed, local_rank=local_rank)
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 539, in train_stage3
#     out = model(x=x, y=y, sensor_tokens=sensor_tokens, h_global=h_global)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model.py", line 159, in forward
#     z0 = self.encoder(x)
#          ^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/skeleton_model.py", line 42, in forward
#     z = t_block(z)
#         ^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/graph_modules.py", line 224, in forward
#     y = self.norm(y)
#         ^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/normalization.py", line 217, in forward
#     return F.layer_norm(
#            ^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/functional.py", line 2900, in layer_norm
#     return torch.layer_norm(
#            ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
# Exception ignored in atexit callback: <function _MultiProcessingDataLoaderIter._clean_up_worker at 0x7f21878e0220>
# Traceback (most recent call last):
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1598, in _clean_up_worker
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/multiprocessing/connection.py", line 948, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:

# %%
# !python train.py \
  --stage 3 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 --batch_size 4 --epochs 20 \
  --lr 5e-5 --no_amp \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
  --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable
# Out:
# 2026-03-01 22:26:18,589 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-01 22:26:18,589 | INFO | train | Run dir: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable
# 2026-03-01 22:26:18,589 | INFO | train | Device: cuda
# 2026-03-01 22:26:18,589 | INFO | train | Config: stage=3 epochs=20 batch_size=4 lr=5e-05 window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# 2026-03-01 22:26:18,589 | INFO | train | Data mode: csv-folders
# 2026-03-01 22:26:18,589 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-01 22:26:18,589 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-01 22:26:18,589 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# /home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# /home/qsw26/smartfall/gait_loss/ldm/train.py:503: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-01 22:26:31,762 | INFO | train | Dataset: CSVPairedGaitDataset samples=5446 batches_per_epoch=1361 drop_last=True
# 2026-03-01 22:28:55,755 | INFO | train | [Stage3] epoch=1/20 loss_total=80.270648 loss_diff=80.153767 loss_cls=1.168825 epoch_time=144.0s
# Saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt
# 2026-03-01 22:28:55,850 | INFO | train | [Stage3] new best checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt (epoch=1 loss_total=80.270648)
# 2026-03-01 22:31:20,463 | INFO | train | [Stage3] epoch=2/20 loss_total=2.037681 loss_diff=1.977003 loss_cls=0.606778 epoch_time=144.6s
# Saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt
# 2026-03-01 22:31:20,650 | INFO | train | [Stage3] new best checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt (epoch=2 loss_total=2.037681)
# 2026-03-01 22:33:42,977 | INFO | train | [Stage3] epoch=3/20 loss_total=2.531605 loss_diff=2.484935 loss_cls=0.466702 epoch_time=142.3s
# 2026-03-01 22:36:04,728 | INFO | train | [Stage3] epoch=4/20 loss_total=2.655546 loss_diff=2.612256 loss_cls=0.432905 epoch_time=141.8s
# 2026-03-01 22:38:26,338 | INFO | train | [Stage3] epoch=5/20 loss_total=3.026383 loss_diff=2.992880 loss_cls=0.335026 epoch_time=141.6s
# 2026-03-01 22:40:47,939 | INFO | train | [Stage3] epoch=6/20 loss_total=2.899408 loss_diff=2.868140 loss_cls=0.312685 epoch_time=141.6s
# 2026-03-01 22:43:09,413 | INFO | train | [Stage3] epoch=7/20 loss_total=2.743043 loss_diff=2.715572 loss_cls=0.274719 epoch_time=141.5s
# 2026-03-01 22:45:30,985 | INFO | train | [Stage3] epoch=8/20 loss_total=2.915685 loss_diff=2.890127 loss_cls=0.255578 epoch_time=141.6s
# 2026-03-01 22:47:52,555 | INFO | train | [Stage3] epoch=9/20 loss_total=2.822066 loss_diff=2.797817 loss_cls=0.242496 epoch_time=141.6s
# 2026-03-01 22:50:15,346 | INFO | train | [Stage3] epoch=10/20 loss_total=2.676326 loss_diff=2.655385 loss_cls=0.209412 epoch_time=142.8s
# 2026-03-01 22:52:36,935 | INFO | train | [Stage3] epoch=11/20 loss_total=2.776017 loss_diff=2.757802 loss_cls=0.182154 epoch_time=141.6s
# 2026-03-01 22:54:58,327 | INFO | train | [Stage3] epoch=12/20 loss_total=2.836151 loss_diff=2.818232 loss_cls=0.179184 epoch_time=141.4s
# 2026-03-01 22:57:19,813 | INFO | train | [Stage3] epoch=13/20 loss_total=2.723781 loss_diff=2.708987 loss_cls=0.147938 epoch_time=141.5s
# 2026-03-01 22:59:42,084 | INFO | train | [Stage3] epoch=14/20 loss_total=2.431951 loss_diff=2.417417 loss_cls=0.145342 epoch_time=142.3s
# 2026-03-01 23:02:03,501 | INFO | train | [Stage3] epoch=15/20 loss_total=2.577472 loss_diff=2.564181 loss_cls=0.132906 epoch_time=141.4s
# 2026-03-01 23:04:24,780 | INFO | train | [Stage3] epoch=16/20 loss_total=2.769087 loss_diff=2.754327 loss_cls=0.147602 epoch_time=141.3s
# 2026-03-01 23:06:46,156 | INFO | train | [Stage3] epoch=17/20 loss_total=2.804510 loss_diff=2.793402 loss_cls=0.111080 epoch_time=141.4s
# 2026-03-01 23:09:07,570 | INFO | train | [Stage3] epoch=18/20 loss_total=3.002022 loss_diff=2.991056 loss_cls=0.109659 epoch_time=141.4s
# 2026-03-01 23:11:29,708 | INFO | train | [Stage3] epoch=19/20 loss_total=2.557507 loss_diff=2.548158 loss_cls=0.093493 epoch_time=142.1s
# 2026-03-01 23:13:53,237 | INFO | train | [Stage3] epoch=20/20 loss_total=2.469303 loss_diff=2.460050 loss_cls=0.092527 epoch_time=143.5s
# Saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3.pt
# 2026-03-01 23:13:53,332 | INFO | train | [Stage3] saved checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3.pt

# %%
# !python generate.py \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
  --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt \
  --stage3_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 --batch_size 1 \
  --save_gif --gif_dir /home/qsw26/smartfall/gait_loss/ldm/outputs/gifs --gif_prefix stage3_stable
# Out:
# /home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3_stable/stage3_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# h_global shape: (1, 256)
# z0_gen shape: (1, 90, 32, 256)
# x_hat shape: (1, 90, 32, 3)
# predicted class for sample[0]: id=10 name=A11
# saved gif: /home/qsw26/smartfall/gait_loss/ldm/outputs/gifs/stage3_stable_A11.gif

# %%
# !python generate.py \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt \
  --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal/stage2.pt \
  --stage3_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 \
  --stride 45 \
  --batch_size 4 \
  --timesteps 500 \
  --save_gif \
  --gif_index 1 \
  --target_class A03 \
  --gif_dir /home/qsw26/smartfall/gait_loss/ldm/outputs/gifs \
  --gif_prefix stage3_single
# Out:
# /home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage1.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/proposal/stage2.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/stage3.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# conditioning sample class: id=2 name=A03
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm/generate.py", line 285, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm/generate.py", line 246, in main
#     x_try, logits_try, z0_try, h_global_try = _sample_once()
#                                               ^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/generate.py", line 221, in _sample_once
#     z0_local = stage3.diffusion.p_sample_loop(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/diffusion.py", line 142, in p_sample_loop
#     z = self.p_sample(denoiser=denoiser, zt=z, t=t, sensor_tokens=h_tokens, h_tokens=h_tokens, h_global=h_global)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/diffusion.py", line 106, in p_sample
#     pred_noise = denoiser(zt, t, sensor_tokens=h_tokens, h_tokens=h_tokens, h_global=h_global)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/skeleton_model.py", line 134, in forward
#     x = c_block(x, h_tokens)
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/graph_modules.py", line 199, in forward
#     attn_out, _ = self.attn(qn, kv, kv)
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/activation.py", line 1368, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/functional.py", line 6097, in multi_head_attention_forward
#     q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/functional.py", line 5523, in _in_projection_packed
#     .unsqueeze(0)
#      ^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
