# %%
# !CUDA_VISIBLE_DEVICES=1 python train.py \
  --stage 2 \
  --stage1_ckpt new_checkpoints/gcnn_stage1/stage1_best.pt \
    --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
    --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone \
    --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch \
     --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
    --encoder_type gcn \
  --lambda_supcon 0.1 \
  --lambda_cls_s2 1 \
  --gait_cache_dir outputs/gait_cache \
  --save_dir new_checkpoints/stage1_gcnn_stage_2_withCE \
  --batch_size 256 \
  --epochs 100 \
  --report_dir /home/qsw26/smartfall/gait_loss/ldm_with_loss/reports/stage1 \
  --run_name stage1_gcnn_stage_2_withCE \
  --imu_graph multiscale
# Out:
# 2026-03-30 01:45:54.944634: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-30 01:46:01,059 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-30 01:46:01,060 | INFO | train | Run dir: new_checkpoints/stage1_gcnn_stage_2_withCE
# 2026-03-30 01:46:01,060 | INFO | train | Device: cuda
# 2026-03-30 01:46:01,060 | INFO | train | Config: stage=2 epochs=100 batch_size=256 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500 val_split=0.1
# 2026-03-30 01:46:01,060 | INFO | train | Data mode: csv-folders
# 2026-03-30 01:46:01,060 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/filtered_skeleton_data
# 2026-03-30 01:46:01,060 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone
# 2026-03-30 01:46:01,060 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch
# 2026-03-30 01:46:01,060 | INFO | train | gait_cache_dir=outputs/gait_cache
# 2026-03-30 01:46:01,060 | INFO | train | Gait metrics dim: 9
# 2026-03-30 01:46:01,061 | INFO | train | Gait metric names: Mean CoM Fore Aft, StDev CoM Fore Aft, Mean CoM Width, StDev CoM Width, Mean CoM Height, StDev CoM Height, Mean Walking Speed, Mean Stride Width, Mean Base of Support
# 2026-03-30 01:46:01,061 | INFO | train | IMU feature names: ax, ay, az, magnitude, pitch, roll
# 2026-03-30 01:46:01,061 | INFO | train | One-to-one mode: True
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: new_checkpoints/gcnn_stage1/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
# 2026-03-30 01:47:01,780 | INFO | train | Subject-wise split enabled.
# 2026-03-30 01:47:01,780 | INFO | train | Train subjects: [29, 30, 31, 32, 35, 36, 37, 38, 39, 43, 44, 45, 46, 49, 51, 56, 57, 58, 59, 61, 62]
# 2026-03-30 01:47:01,780 | INFO | train | Val subjects: [34, 48, 50, 52, 53, 54, 55, 60, 63]
# 2026-03-30 01:47:01,781 | INFO | train | Train samples=3010 Val samples=1395
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py:644: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-30 01:47:01,783 | INFO | train | Dataset: Subset samples=3010 batches_per_epoch=11 drop_last=True
# 2026-03-30 01:47:01,783 | INFO | train | Validation: samples=1395 batches=6 drop_last=False
# 2026-03-30 01:47:15,043 | INFO | train | [Stage2] epoch=1/100 train_loss_total=3.915135 train_loss_align=0.712139 train_loss_supcon=5.671341 train_loss_cls=2.635862 val_loss_total=3.647926 val_loss_align=0.496450 val_loss_supcon=5.250173 val_loss_cls=2.626459 epoch_time=13.3s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:15,146 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=1 monitor_loss=3.647926)
# 2026-03-30 01:47:23,517 | INFO | train | [Stage2] epoch=2/100 train_loss_total=3.572482 train_loss_align=0.403565 train_loss_supcon=5.508008 train_loss_cls=2.618117 val_loss_total=3.431798 val_loss_align=0.292937 val_loss_supcon=5.280377 val_loss_cls=2.610823 epoch_time=8.4s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:23,612 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=2 monitor_loss=3.431798)
# 2026-03-30 01:47:31,449 | INFO | train | [Stage2] epoch=3/100 train_loss_total=3.427216 train_loss_align=0.273895 train_loss_supcon=5.503907 train_loss_cls=2.602931 val_loss_total=3.344312 val_loss_align=0.218064 val_loss_supcon=5.294221 val_loss_cls=2.596826 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:31,502 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=3 monitor_loss=3.344312)
# 2026-03-30 01:47:39,504 | INFO | train | [Stage2] epoch=4/100 train_loss_total=3.362802 train_loss_align=0.224164 train_loss_supcon=5.492660 train_loss_cls=2.589371 val_loss_total=3.303978 val_loss_align=0.191165 val_loss_supcon=5.291513 val_loss_cls=2.583662 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:39,565 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=4 monitor_loss=3.303978)
# 2026-03-30 01:47:47,576 | INFO | train | [Stage2] epoch=5/100 train_loss_total=3.328511 train_loss_align=0.206065 train_loss_supcon=5.490576 train_loss_cls=2.573389 val_loss_total=3.278157 val_loss_align=0.181577 val_loss_supcon=5.280579 val_loss_cls=2.568522 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:47,646 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=5 monitor_loss=3.278157)
# 2026-03-30 01:47:55,525 | INFO | train | [Stage2] epoch=6/100 train_loss_total=3.303187 train_loss_align=0.202490 train_loss_supcon=5.478767 train_loss_cls=2.552820 val_loss_total=3.254123 val_loss_align=0.180336 val_loss_supcon=5.260948 val_loss_cls=2.547692 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:47:55,602 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=6 monitor_loss=3.254123)
# 2026-03-30 01:48:03,150 | INFO | train | [Stage2] epoch=7/100 train_loss_total=3.280097 train_loss_align=0.201944 train_loss_supcon=5.475448 train_loss_cls=2.530608 val_loss_total=3.227945 val_loss_align=0.180838 val_loss_supcon=5.242787 val_loss_cls=2.522828 epoch_time=7.5s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:03,219 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=7 monitor_loss=3.227945)
# 2026-03-30 01:48:11,285 | INFO | train | [Stage2] epoch=8/100 train_loss_total=3.250810 train_loss_align=0.202417 train_loss_supcon=5.475304 train_loss_cls=2.500863 val_loss_total=3.196259 val_loss_align=0.180149 val_loss_supcon=5.225676 val_loss_cls=2.493542 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:11,352 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=8 monitor_loss=3.196259)
# 2026-03-30 01:48:19,267 | INFO | train | [Stage2] epoch=9/100 train_loss_total=3.215748 train_loss_align=0.201669 train_loss_supcon=5.481519 train_loss_cls=2.465927 val_loss_total=3.156098 val_loss_align=0.180186 val_loss_supcon=5.213304 val_loss_cls=2.454581 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:19,400 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=9 monitor_loss=3.156098)
# 2026-03-30 01:48:27,180 | INFO | train | [Stage2] epoch=10/100 train_loss_total=3.180372 train_loss_align=0.203785 train_loss_supcon=5.496720 train_loss_cls=2.426915 val_loss_total=3.120094 val_loss_align=0.182382 val_loss_supcon=5.207637 val_loss_cls=2.416948 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:27,233 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=10 monitor_loss=3.120094)
# 2026-03-30 01:48:35,270 | INFO | train | [Stage2] epoch=11/100 train_loss_total=3.135673 train_loss_align=0.203945 train_loss_supcon=5.491319 train_loss_cls=2.382596 val_loss_total=3.080684 val_loss_align=0.186030 val_loss_supcon=5.208310 val_loss_cls=2.373823 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:35,360 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=11 monitor_loss=3.080684)
# 2026-03-30 01:48:43,019 | INFO | train | [Stage2] epoch=12/100 train_loss_total=3.094486 train_loss_align=0.206547 train_loss_supcon=5.518619 train_loss_cls=2.336077 val_loss_total=3.036334 val_loss_align=0.185524 val_loss_supcon=5.203639 val_loss_cls=2.330446 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:43,076 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=12 monitor_loss=3.036334)
# 2026-03-30 01:48:50,860 | INFO | train | [Stage2] epoch=13/100 train_loss_total=3.048205 train_loss_align=0.206507 train_loss_supcon=5.503741 train_loss_cls=2.291324 val_loss_total=2.988190 val_loss_align=0.181316 val_loss_supcon=5.194860 val_loss_cls=2.287388 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:51,016 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=13 monitor_loss=2.988190)
# 2026-03-30 01:48:58,888 | INFO | train | [Stage2] epoch=14/100 train_loss_total=3.010639 train_loss_align=0.205309 train_loss_supcon=5.482292 train_loss_cls=2.257101 val_loss_total=2.985052 val_loss_align=0.185423 val_loss_supcon=5.195403 val_loss_cls=2.280089 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:48:58,948 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=14 monitor_loss=2.985052)
# 2026-03-30 01:49:06,534 | INFO | train | [Stage2] epoch=15/100 train_loss_total=2.964006 train_loss_align=0.205349 train_loss_supcon=5.476943 train_loss_cls=2.210963 val_loss_total=2.928898 val_loss_align=0.180661 val_loss_supcon=5.186215 val_loss_cls=2.229615 epoch_time=7.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:49:06,592 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=15 monitor_loss=2.928898)
# 2026-03-30 01:49:14,761 | INFO | train | [Stage2] epoch=16/100 train_loss_total=2.919307 train_loss_align=0.204104 train_loss_supcon=5.450040 train_loss_cls=2.170199 val_loss_total=2.933604 val_loss_align=0.181589 val_loss_supcon=5.185930 val_loss_cls=2.233423 epoch_time=8.2s
# 2026-03-30 01:49:22,683 | INFO | train | [Stage2] epoch=17/100 train_loss_total=2.891277 train_loss_align=0.204025 train_loss_supcon=5.442707 train_loss_cls=2.142981 val_loss_total=2.905265 val_loss_align=0.178833 val_loss_supcon=5.188371 val_loss_cls=2.207596 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:49:22,763 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=17 monitor_loss=2.905265)
# 2026-03-30 01:49:30,860 | INFO | train | [Stage2] epoch=18/100 train_loss_total=2.860988 train_loss_align=0.204175 train_loss_supcon=5.436376 train_loss_cls=2.113175 val_loss_total=2.877089 val_loss_align=0.176604 val_loss_supcon=5.189389 val_loss_cls=2.181546 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:49:30,962 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=18 monitor_loss=2.877089)
# 2026-03-30 01:49:39,048 | INFO | train | [Stage2] epoch=19/100 train_loss_total=2.843025 train_loss_align=0.203212 train_loss_supcon=5.436251 train_loss_cls=2.096188 val_loss_total=2.871643 val_loss_align=0.174614 val_loss_supcon=5.192811 val_loss_cls=2.177748 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:49:39,171 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=19 monitor_loss=2.871643)
# 2026-03-30 01:49:47,044 | INFO | train | [Stage2] epoch=20/100 train_loss_total=2.814482 train_loss_align=0.201919 train_loss_supcon=5.425799 train_loss_cls=2.069982 val_loss_total=2.878433 val_loss_align=0.173777 val_loss_supcon=5.194324 val_loss_cls=2.185224 epoch_time=7.9s
# 2026-03-30 01:49:55,143 | INFO | train | [Stage2] epoch=21/100 train_loss_total=2.781270 train_loss_align=0.199567 train_loss_supcon=5.409539 train_loss_cls=2.040750 val_loss_total=2.878892 val_loss_align=0.173191 val_loss_supcon=5.194684 val_loss_cls=2.186233 epoch_time=8.1s
# 2026-03-30 01:50:02,594 | INFO | train | [Stage2] epoch=22/100 train_loss_total=2.764741 train_loss_align=0.199744 train_loss_supcon=5.408225 train_loss_cls=2.024175 val_loss_total=2.864635 val_loss_align=0.173332 val_loss_supcon=5.195936 val_loss_cls=2.171710 epoch_time=7.5s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:50:02,684 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=22 monitor_loss=2.864635)
# 2026-03-30 01:50:10,743 | INFO | train | [Stage2] epoch=23/100 train_loss_total=2.743130 train_loss_align=0.197619 train_loss_supcon=5.393992 train_loss_cls=2.006112 val_loss_total=2.877881 val_loss_align=0.172107 val_loss_supcon=5.199283 val_loss_cls=2.185845 epoch_time=8.1s
# 2026-03-30 01:50:18,771 | INFO | train | [Stage2] epoch=24/100 train_loss_total=2.723898 train_loss_align=0.197348 train_loss_supcon=5.389099 train_loss_cls=1.987640 val_loss_total=2.857361 val_loss_align=0.171083 val_loss_supcon=5.198391 val_loss_cls=2.166439 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:50:18,830 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=24 monitor_loss=2.857361)
# 2026-03-30 01:50:26,566 | INFO | train | [Stage2] epoch=25/100 train_loss_total=2.709323 train_loss_align=0.196429 train_loss_supcon=5.387829 train_loss_cls=1.974112 val_loss_total=2.874910 val_loss_align=0.172232 val_loss_supcon=5.198783 val_loss_cls=2.182800 epoch_time=7.7s
# 2026-03-30 01:50:34,279 | INFO | train | [Stage2] epoch=26/100 train_loss_total=2.695906 train_loss_align=0.196200 train_loss_supcon=5.386100 train_loss_cls=1.961096 val_loss_total=2.861339 val_loss_align=0.170006 val_loss_supcon=5.201388 val_loss_cls=2.171195 epoch_time=7.7s
# 2026-03-30 01:50:41,990 | INFO | train | [Stage2] epoch=27/100 train_loss_total=2.679112 train_loss_align=0.195273 train_loss_supcon=5.370940 train_loss_cls=1.946744 val_loss_total=2.861401 val_loss_align=0.170557 val_loss_supcon=5.203797 val_loss_cls=2.170464 epoch_time=7.7s
# 2026-03-30 01:50:50,149 | INFO | train | [Stage2] epoch=28/100 train_loss_total=2.666060 train_loss_align=0.193980 train_loss_supcon=5.363667 train_loss_cls=1.935712 val_loss_total=2.897404 val_loss_align=0.170645 val_loss_supcon=5.201038 val_loss_cls=2.206656 epoch_time=8.2s
# 2026-03-30 01:50:58,414 | INFO | train | [Stage2] epoch=29/100 train_loss_total=2.641992 train_loss_align=0.193358 train_loss_supcon=5.359628 train_loss_cls=1.912672 val_loss_total=2.843425 val_loss_align=0.168953 val_loss_supcon=5.202646 val_loss_cls=2.154208 epoch_time=8.3s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:50:58,532 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=29 monitor_loss=2.843425)
# 2026-03-30 01:51:06,169 | INFO | train | [Stage2] epoch=30/100 train_loss_total=2.622015 train_loss_align=0.191747 train_loss_supcon=5.357565 train_loss_cls=1.894512 val_loss_total=2.849244 val_loss_align=0.168793 val_loss_supcon=5.200763 val_loss_cls=2.160375 epoch_time=7.6s
# 2026-03-30 01:51:13,951 | INFO | train | [Stage2] epoch=31/100 train_loss_total=2.618884 train_loss_align=0.192155 train_loss_supcon=5.353016 train_loss_cls=1.891428 val_loss_total=2.847054 val_loss_align=0.169117 val_loss_supcon=5.200913 val_loss_cls=2.157845 epoch_time=7.8s
# 2026-03-30 01:51:21,599 | INFO | train | [Stage2] epoch=32/100 train_loss_total=2.613414 train_loss_align=0.191276 train_loss_supcon=5.353575 train_loss_cls=1.886780 val_loss_total=2.874995 val_loss_align=0.169603 val_loss_supcon=5.200927 val_loss_cls=2.185299 epoch_time=7.6s
# 2026-03-30 01:51:29,594 | INFO | train | [Stage2] epoch=33/100 train_loss_total=2.598706 train_loss_align=0.190930 train_loss_supcon=5.348331 train_loss_cls=1.872942 val_loss_total=2.885741 val_loss_align=0.170163 val_loss_supcon=5.195493 val_loss_cls=2.196029 epoch_time=8.0s
# 2026-03-30 01:51:37,568 | INFO | train | [Stage2] epoch=34/100 train_loss_total=2.591573 train_loss_align=0.191141 train_loss_supcon=5.343446 train_loss_cls=1.866087 val_loss_total=2.826818 val_loss_align=0.167234 val_loss_supcon=5.197072 val_loss_cls=2.139877 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:51:37,662 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=34 monitor_loss=2.826818)
# 2026-03-30 01:51:45,741 | INFO | train | [Stage2] epoch=35/100 train_loss_total=2.568435 train_loss_align=0.189019 train_loss_supcon=5.336984 train_loss_cls=1.845717 val_loss_total=2.850097 val_loss_align=0.167979 val_loss_supcon=5.196805 val_loss_cls=2.162437 epoch_time=8.1s
# 2026-03-30 01:51:53,853 | INFO | train | [Stage2] epoch=36/100 train_loss_total=2.559186 train_loss_align=0.188600 train_loss_supcon=5.332173 train_loss_cls=1.837369 val_loss_total=2.847244 val_loss_align=0.167885 val_loss_supcon=5.193855 val_loss_cls=2.159973 epoch_time=8.1s
# 2026-03-30 01:52:01,711 | INFO | train | [Stage2] epoch=37/100 train_loss_total=2.546829 train_loss_align=0.188558 train_loss_supcon=5.325438 train_loss_cls=1.825727 val_loss_total=2.859229 val_loss_align=0.167091 val_loss_supcon=5.192516 val_loss_cls=2.172887 epoch_time=7.9s
# 2026-03-30 01:52:09,475 | INFO | train | [Stage2] epoch=38/100 train_loss_total=2.542623 train_loss_align=0.188459 train_loss_supcon=5.326667 train_loss_cls=1.821497 val_loss_total=2.823423 val_loss_align=0.166459 val_loss_supcon=5.194127 val_loss_cls=2.137551 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:52:09,535 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=38 monitor_loss=2.823423)
# 2026-03-30 01:52:17,473 | INFO | train | [Stage2] epoch=39/100 train_loss_total=2.526912 train_loss_align=0.188073 train_loss_supcon=5.323173 train_loss_cls=1.806522 val_loss_total=2.841886 val_loss_align=0.167029 val_loss_supcon=5.192855 val_loss_cls=2.155572 epoch_time=7.9s
# 2026-03-30 01:52:25,143 | INFO | train | [Stage2] epoch=40/100 train_loss_total=2.519094 train_loss_align=0.186999 train_loss_supcon=5.322045 train_loss_cls=1.799891 val_loss_total=2.841321 val_loss_align=0.166195 val_loss_supcon=5.190349 val_loss_cls=2.156090 epoch_time=7.7s
# 2026-03-30 01:52:32,957 | INFO | train | [Stage2] epoch=41/100 train_loss_total=2.515811 train_loss_align=0.186689 train_loss_supcon=5.320637 train_loss_cls=1.797058 val_loss_total=2.857322 val_loss_align=0.166535 val_loss_supcon=5.189096 val_loss_cls=2.171877 epoch_time=7.8s
# 2026-03-30 01:52:40,930 | INFO | train | [Stage2] epoch=42/100 train_loss_total=2.507605 train_loss_align=0.185601 train_loss_supcon=5.323371 train_loss_cls=1.789667 val_loss_total=2.825870 val_loss_align=0.164743 val_loss_supcon=5.192345 val_loss_cls=2.141893 epoch_time=8.0s
# 2026-03-30 01:52:48,880 | INFO | train | [Stage2] epoch=43/100 train_loss_total=2.479312 train_loss_align=0.185586 train_loss_supcon=5.308466 train_loss_cls=1.762879 val_loss_total=2.827554 val_loss_align=0.166571 val_loss_supcon=5.188879 val_loss_cls=2.142096 epoch_time=8.0s
# 2026-03-30 01:52:57,009 | INFO | train | [Stage2] epoch=44/100 train_loss_total=2.489568 train_loss_align=0.185470 train_loss_supcon=5.316738 train_loss_cls=1.772424 val_loss_total=2.830828 val_loss_align=0.165073 val_loss_supcon=5.186579 val_loss_cls=2.147097 epoch_time=8.1s
# 2026-03-30 01:53:04,619 | INFO | train | [Stage2] epoch=45/100 train_loss_total=2.474573 train_loss_align=0.186137 train_loss_supcon=5.310961 train_loss_cls=1.757340 val_loss_total=2.827722 val_loss_align=0.165539 val_loss_supcon=5.186729 val_loss_cls=2.143511 epoch_time=7.6s
# 2026-03-30 01:53:12,653 | INFO | train | [Stage2] epoch=46/100 train_loss_total=2.467498 train_loss_align=0.185836 train_loss_supcon=5.308170 train_loss_cls=1.750845 val_loss_total=2.829621 val_loss_align=0.164843 val_loss_supcon=5.185566 val_loss_cls=2.146222 epoch_time=8.0s
# 2026-03-30 01:53:20,483 | INFO | train | [Stage2] epoch=47/100 train_loss_total=2.467119 train_loss_align=0.184202 train_loss_supcon=5.307453 train_loss_cls=1.752171 val_loss_total=2.824931 val_loss_align=0.164695 val_loss_supcon=5.184570 val_loss_cls=2.141780 epoch_time=7.8s
# 2026-03-30 01:53:28,447 | INFO | train | [Stage2] epoch=48/100 train_loss_total=2.454625 train_loss_align=0.184402 train_loss_supcon=5.304875 train_loss_cls=1.739735 val_loss_total=2.823423 val_loss_align=0.164758 val_loss_supcon=5.184896 val_loss_cls=2.140175 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:53:28,568 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=48 monitor_loss=2.823423)
# 2026-03-30 01:53:36,715 | INFO | train | [Stage2] epoch=49/100 train_loss_total=2.457632 train_loss_align=0.183712 train_loss_supcon=5.301054 train_loss_cls=1.743814 val_loss_total=2.819397 val_loss_align=0.164317 val_loss_supcon=5.185249 val_loss_cls=2.136555 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# 2026-03-30 01:53:36,868 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt (epoch=49 monitor_loss=2.819397)
# 2026-03-30 01:53:45,046 | INFO | train | [Stage2] epoch=50/100 train_loss_total=2.454511 train_loss_align=0.184321 train_loss_supcon=5.305799 train_loss_cls=1.739610 val_loss_total=2.813716 val_loss_align=0.164264 val_loss_supcon=5.184566 val_loss_cls=2.130995 epoch_time=8.2s
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 1244, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 1233, in main
#     train_stage2(args, device, distributed=distributed, local_rank=local_rank)
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 787, in train_stage2
#     evaluate_stage2(
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/training_eval.py", line 747, in evaluate_stage2
#     z0 = stage1.encoder(x, gait_metrics=gait_metrics)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/skeleton_model.py", line 140, in forward
#     z = g_block(z, adjacency=adjacency, edge_index=edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/graph_modules.py", line 162, in forward
#     x = x + self.ff(self.norm2(x))
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/activation.py", line 734, in forward
#     return F.gelu(input, approximate=self.approximate)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.81 GiB. GPU 0 has a total capacity of 23.68 GiB of which 385.44 MiB is free. Process 3535097 has 2.65 GiB memory in use. Process 3536290 has 6.70 GiB memory in use. Process 3586864 has 3.57 GiB memory in use. Including non-PyTorch memory, this process has 10.37 GiB memory in use. Of the allocated memory 6.94 GiB is allocated by PyTorch, and 3.18 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# !CUDA_VISIBLE_DEVICES=1 python train.py \
  --stage 2 \
  --stage1_ckpt new_checkpoints/gcnn_stage1/stage1_best.pt \
    --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
    --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone \
    --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch \
    --val_split 0.2 \
    --encoder_type gcn \
  --lambda_supcon 0.1 \
  --lambda_cls_s2 1 \
  --gait_cache_dir outputs/gait_cache \
  --save_dir new_checkpoints/stage1_gcnn_stage_2_withCE_window \
  --batch_size 256 \
  --epochs 100 \
  --report_dir /home/qsw26/smartfall/gait_loss/ldm_with_loss/reports/stage1 \
  --run_name stage1_gcnn_stage_2_withCE_window \
  --imu_graph multiscale
# Out:
# 2026-03-30 01:55:49.319183: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-30 01:55:55,484 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-30 01:55:55,484 | INFO | train | Run dir: new_checkpoints/stage1_gcnn_stage_2_withCE_window
# 2026-03-30 01:55:55,490 | INFO | train | Device: cuda
# 2026-03-30 01:55:55,491 | INFO | train | Config: stage=2 epochs=100 batch_size=256 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500 val_split=0.2
# 2026-03-30 01:55:55,491 | INFO | train | Data mode: csv-folders
# 2026-03-30 01:55:55,491 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/filtered_skeleton_data
# 2026-03-30 01:55:55,491 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone
# 2026-03-30 01:55:55,491 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch
# 2026-03-30 01:55:55,491 | INFO | train | gait_cache_dir=outputs/gait_cache
# 2026-03-30 01:55:55,491 | INFO | train | Gait metrics dim: 9
# 2026-03-30 01:55:55,491 | INFO | train | Gait metric names: Mean CoM Fore Aft, StDev CoM Fore Aft, Mean CoM Width, StDev CoM Width, Mean CoM Height, StDev CoM Height, Mean Walking Speed, Mean Stride Width, Mean Base of Support
# 2026-03-30 01:55:55,491 | INFO | train | IMU feature names: ax, ay, az, magnitude, pitch, roll
# 2026-03-30 01:55:55,491 | INFO | train | One-to-one mode: True
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: new_checkpoints/gcnn_stage1/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py:644: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-30 01:56:48,535 | INFO | train | Dataset: Subset samples=3524 batches_per_epoch=13 drop_last=True
# 2026-03-30 01:56:48,535 | INFO | train | Validation: samples=881 batches=4 drop_last=False
# 2026-03-30 01:57:02,091 | INFO | train | [Stage2] epoch=1/100 train_loss_total=3.874909 train_loss_align=0.676992 train_loss_supcon=5.656170 train_loss_cls=2.632300 val_loss_total=3.612072 val_loss_align=0.455114 val_loss_supcon=5.301872 val_loss_cls=2.626771 epoch_time=13.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:02,202 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=1 monitor_loss=3.612072)
# 2026-03-30 01:57:10,299 | INFO | train | [Stage2] epoch=2/100 train_loss_total=3.512816 train_loss_align=0.351108 train_loss_supcon=5.507008 train_loss_cls=2.611007 val_loss_total=3.411272 val_loss_align=0.272177 val_loss_supcon=5.287867 val_loss_cls=2.610309 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:10,402 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=2 monitor_loss=3.411272)
# 2026-03-30 01:57:19,197 | INFO | train | [Stage2] epoch=3/100 train_loss_total=3.381848 train_loss_align=0.238975 train_loss_supcon=5.493238 train_loss_cls=2.593549 val_loss_total=3.336858 val_loss_align=0.215509 val_loss_supcon=5.281952 val_loss_cls=2.593154 epoch_time=8.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:19,349 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=3 monitor_loss=3.336858)
# 2026-03-30 01:57:27,241 | INFO | train | [Stage2] epoch=4/100 train_loss_total=3.325046 train_loss_align=0.202391 train_loss_supcon=5.485746 train_loss_cls=2.574081 val_loss_total=3.298819 val_loss_align=0.198877 val_loss_supcon=5.274309 val_loss_cls=2.572511 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:27,306 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=4 monitor_loss=3.298819)
# 2026-03-30 01:57:35,125 | INFO | train | [Stage2] epoch=5/100 train_loss_total=3.293561 train_loss_align=0.194413 train_loss_supcon=5.477754 train_loss_cls=2.551372 val_loss_total=3.269850 val_loss_align=0.196170 val_loss_supcon=5.268922 val_loss_cls=2.546787 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:35,220 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=5 monitor_loss=3.269850)
# 2026-03-30 01:57:42,929 | INFO | train | [Stage2] epoch=6/100 train_loss_total=3.261143 train_loss_align=0.193435 train_loss_supcon=5.469272 train_loss_cls=2.520781 val_loss_total=3.238390 val_loss_align=0.196411 val_loss_supcon=5.272071 val_loss_cls=2.514772 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:42,972 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=6 monitor_loss=3.238390)
# 2026-03-30 01:57:50,757 | INFO | train | [Stage2] epoch=7/100 train_loss_total=3.223392 train_loss_align=0.193715 train_loss_supcon=5.470505 train_loss_cls=2.482627 val_loss_total=3.199477 val_loss_align=0.197884 val_loss_supcon=5.291052 val_loss_cls=2.472488 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:50,810 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=7 monitor_loss=3.199477)
# 2026-03-30 01:57:58,610 | INFO | train | [Stage2] epoch=8/100 train_loss_total=3.177789 train_loss_align=0.194377 train_loss_supcon=5.488167 train_loss_cls=2.434595 val_loss_total=3.154531 val_loss_align=0.199898 val_loss_supcon=5.322565 val_loss_cls=2.422376 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:57:58,677 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=8 monitor_loss=3.154531)
# 2026-03-30 01:58:06,419 | INFO | train | [Stage2] epoch=9/100 train_loss_total=3.130297 train_loss_align=0.196955 train_loss_supcon=5.512457 train_loss_cls=2.382096 val_loss_total=3.107162 val_loss_align=0.202274 val_loss_supcon=5.342011 val_loss_cls=2.370687 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:06,519 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=9 monitor_loss=3.107162)
# 2026-03-30 01:58:14,631 | INFO | train | [Stage2] epoch=10/100 train_loss_total=3.078524 train_loss_align=0.197139 train_loss_supcon=5.508129 train_loss_cls=2.330573 val_loss_total=3.061349 val_loss_align=0.202858 val_loss_supcon=5.337649 val_loss_cls=2.324726 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:14,749 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=10 monitor_loss=3.061349)
# 2026-03-30 01:58:22,593 | INFO | train | [Stage2] epoch=11/100 train_loss_total=3.034913 train_loss_align=0.197482 train_loss_supcon=5.507983 train_loss_cls=2.286632 val_loss_total=3.018209 val_loss_align=0.203428 val_loss_supcon=5.325153 val_loss_cls=2.282265 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:22,709 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=11 monitor_loss=3.018209)
# 2026-03-30 01:58:30,855 | INFO | train | [Stage2] epoch=12/100 train_loss_total=2.987099 train_loss_align=0.195815 train_loss_supcon=5.472190 train_loss_cls=2.244065 val_loss_total=2.981286 val_loss_align=0.200817 val_loss_supcon=5.296216 val_loss_cls=2.250847 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:30,950 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=12 monitor_loss=2.981286)
# 2026-03-30 01:58:38,614 | INFO | train | [Stage2] epoch=13/100 train_loss_total=2.948655 train_loss_align=0.195401 train_loss_supcon=5.465757 train_loss_cls=2.206678 val_loss_total=2.947631 val_loss_align=0.200425 val_loss_supcon=5.290870 val_loss_cls=2.218119 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:38,673 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=13 monitor_loss=2.947631)
# 2026-03-30 01:58:46,666 | INFO | train | [Stage2] epoch=14/100 train_loss_total=2.918191 train_loss_align=0.193826 train_loss_supcon=5.460317 train_loss_cls=2.178334 val_loss_total=2.920300 val_loss_align=0.198788 val_loss_supcon=5.269763 val_loss_cls=2.194535 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:46,967 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=14 monitor_loss=2.920300)
# 2026-03-30 01:58:54,719 | INFO | train | [Stage2] epoch=15/100 train_loss_total=2.891202 train_loss_align=0.192929 train_loss_supcon=5.439536 train_loss_cls=2.154319 val_loss_total=2.892656 val_loss_align=0.196674 val_loss_supcon=5.256914 val_loss_cls=2.170290 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:58:54,807 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=15 monitor_loss=2.892656)
# 2026-03-30 01:59:02,813 | INFO | train | [Stage2] epoch=16/100 train_loss_total=2.865669 train_loss_align=0.191331 train_loss_supcon=5.439558 train_loss_cls=2.130382 val_loss_total=2.872719 val_loss_align=0.198080 val_loss_supcon=5.255341 val_loss_cls=2.149105 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:02,935 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=16 monitor_loss=2.872719)
# 2026-03-30 01:59:11,044 | INFO | train | [Stage2] epoch=17/100 train_loss_total=2.836233 train_loss_align=0.191021 train_loss_supcon=5.425490 train_loss_cls=2.102663 val_loss_total=2.846541 val_loss_align=0.196604 val_loss_supcon=5.242633 val_loss_cls=2.125674 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:11,115 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=17 monitor_loss=2.846541)
# 2026-03-30 01:59:19,283 | INFO | train | [Stage2] epoch=18/100 train_loss_total=2.815677 train_loss_align=0.189133 train_loss_supcon=5.423838 train_loss_cls=2.084161 val_loss_total=2.824885 val_loss_align=0.195942 val_loss_supcon=5.238559 val_loss_cls=2.105087 epoch_time=8.2s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:19,415 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=18 monitor_loss=2.824885)
# 2026-03-30 01:59:27,313 | INFO | train | [Stage2] epoch=19/100 train_loss_total=2.799368 train_loss_align=0.189599 train_loss_supcon=5.420161 train_loss_cls=2.067753 val_loss_total=2.806893 val_loss_align=0.195963 val_loss_supcon=5.233563 val_loss_cls=2.087574 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:27,368 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=19 monitor_loss=2.806893)
# 2026-03-30 01:59:35,391 | INFO | train | [Stage2] epoch=20/100 train_loss_total=2.777147 train_loss_align=0.188530 train_loss_supcon=5.411252 train_loss_cls=2.047491 val_loss_total=2.787383 val_loss_align=0.193410 val_loss_supcon=5.229597 val_loss_cls=2.071014 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:35,425 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=20 monitor_loss=2.787383)
# 2026-03-30 01:59:43,390 | INFO | train | [Stage2] epoch=21/100 train_loss_total=2.764260 train_loss_align=0.187704 train_loss_supcon=5.414930 train_loss_cls=2.035063 val_loss_total=2.768298 val_loss_align=0.192330 val_loss_supcon=5.219928 val_loss_cls=2.053975 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:43,459 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=21 monitor_loss=2.768298)
# 2026-03-30 01:59:51,649 | INFO | train | [Stage2] epoch=22/100 train_loss_total=2.748344 train_loss_align=0.186774 train_loss_supcon=5.405624 train_loss_cls=2.021007 val_loss_total=2.756625 val_loss_align=0.190885 val_loss_supcon=5.214693 val_loss_cls=2.044270 epoch_time=8.2s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:51,833 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=22 monitor_loss=2.756625)
# 2026-03-30 01:59:59,664 | INFO | train | [Stage2] epoch=23/100 train_loss_total=2.731299 train_loss_align=0.185453 train_loss_supcon=5.405932 train_loss_cls=2.005252 val_loss_total=2.751450 val_loss_align=0.190171 val_loss_supcon=5.208837 val_loss_cls=2.040394 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 01:59:59,745 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=23 monitor_loss=2.751450)
# 2026-03-30 02:00:07,410 | INFO | train | [Stage2] epoch=24/100 train_loss_total=2.711644 train_loss_align=0.185183 train_loss_supcon=5.392921 train_loss_cls=1.987169 val_loss_total=2.729476 val_loss_align=0.189593 val_loss_supcon=5.206236 val_loss_cls=2.019260 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:07,543 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=24 monitor_loss=2.729476)
# 2026-03-30 02:00:15,627 | INFO | train | [Stage2] epoch=25/100 train_loss_total=2.705782 train_loss_align=0.185285 train_loss_supcon=5.398305 train_loss_cls=1.980667 val_loss_total=2.711705 val_loss_align=0.189385 val_loss_supcon=5.201156 val_loss_cls=2.002204 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:15,790 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=25 monitor_loss=2.711705)
# 2026-03-30 02:00:23,631 | INFO | train | [Stage2] epoch=26/100 train_loss_total=2.681243 train_loss_align=0.183273 train_loss_supcon=5.397584 train_loss_cls=1.958212 val_loss_total=2.690689 val_loss_align=0.188875 val_loss_supcon=5.192231 val_loss_cls=1.982591 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:23,803 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=26 monitor_loss=2.690689)
# 2026-03-30 02:00:31,909 | INFO | train | [Stage2] epoch=27/100 train_loss_total=2.662983 train_loss_align=0.181951 train_loss_supcon=5.388601 train_loss_cls=1.942172 val_loss_total=2.677572 val_loss_align=0.188539 val_loss_supcon=5.189711 val_loss_cls=1.970062 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:31,966 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=27 monitor_loss=2.677572)
# 2026-03-30 02:00:40,102 | INFO | train | [Stage2] epoch=28/100 train_loss_total=2.659137 train_loss_align=0.182688 train_loss_supcon=5.386311 train_loss_cls=1.937818 val_loss_total=2.665970 val_loss_align=0.187666 val_loss_supcon=5.184580 val_loss_cls=1.959846 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:40,195 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=28 monitor_loss=2.665970)
# 2026-03-30 02:00:48,025 | INFO | train | [Stage2] epoch=29/100 train_loss_total=2.640579 train_loss_align=0.182230 train_loss_supcon=5.375950 train_loss_cls=1.920754 val_loss_total=2.657713 val_loss_align=0.187251 val_loss_supcon=5.183392 val_loss_cls=1.952123 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:48,089 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=29 monitor_loss=2.657713)
# 2026-03-30 02:00:56,209 | INFO | train | [Stage2] epoch=30/100 train_loss_total=2.630087 train_loss_align=0.181555 train_loss_supcon=5.378606 train_loss_cls=1.910671 val_loss_total=2.644793 val_loss_align=0.187477 val_loss_supcon=5.178687 val_loss_cls=1.939448 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:00:56,295 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=30 monitor_loss=2.644793)
# 2026-03-30 02:01:04,008 | INFO | train | [Stage2] epoch=31/100 train_loss_total=2.610407 train_loss_align=0.180566 train_loss_supcon=5.372411 train_loss_cls=1.892600 val_loss_total=2.629943 val_loss_align=0.187230 val_loss_supcon=5.174161 val_loss_cls=1.925297 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:01:04,072 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=31 monitor_loss=2.629943)
# 2026-03-30 02:01:12,293 | INFO | train | [Stage2] epoch=32/100 train_loss_total=2.600827 train_loss_align=0.180781 train_loss_supcon=5.364299 train_loss_cls=1.883616 val_loss_total=2.623719 val_loss_align=0.187053 val_loss_supcon=5.170255 val_loss_cls=1.919640 epoch_time=8.2s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:01:12,396 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=32 monitor_loss=2.623719)
# 2026-03-30 02:01:20,124 | INFO | train | [Stage2] epoch=33/100 train_loss_total=2.607258 train_loss_align=0.180604 train_loss_supcon=5.375582 train_loss_cls=1.889096 val_loss_total=2.631396 val_loss_align=0.186035 val_loss_supcon=5.171443 val_loss_cls=1.928216 epoch_time=7.7s
# 2026-03-30 02:01:27,744 | INFO | train | [Stage2] epoch=34/100 train_loss_total=2.591182 train_loss_align=0.180561 train_loss_supcon=5.367687 train_loss_cls=1.873853 val_loss_total=2.608951 val_loss_align=0.184943 val_loss_supcon=5.163808 val_loss_cls=1.907627 epoch_time=7.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:01:27,834 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=34 monitor_loss=2.608951)
# 2026-03-30 02:01:36,088 | INFO | train | [Stage2] epoch=35/100 train_loss_total=2.576856 train_loss_align=0.180048 train_loss_supcon=5.356762 train_loss_cls=1.861131 val_loss_total=2.616359 val_loss_align=0.184333 val_loss_supcon=5.162247 val_loss_cls=1.915801 epoch_time=8.3s
# 2026-03-30 02:01:44,652 | INFO | train | [Stage2] epoch=36/100 train_loss_total=2.562015 train_loss_align=0.178795 train_loss_supcon=5.353312 train_loss_cls=1.847889 val_loss_total=2.601941 val_loss_align=0.185076 val_loss_supcon=5.161705 val_loss_cls=1.900695 epoch_time=8.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:01:44,684 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=36 monitor_loss=2.601941)
# 2026-03-30 02:01:52,564 | INFO | train | [Stage2] epoch=37/100 train_loss_total=2.556697 train_loss_align=0.178624 train_loss_supcon=5.356891 train_loss_cls=1.842384 val_loss_total=2.582269 val_loss_align=0.184210 val_loss_supcon=5.157479 val_loss_cls=1.882311 epoch_time=7.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:01:52,794 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=37 monitor_loss=2.582269)
# 2026-03-30 02:02:00,486 | INFO | train | [Stage2] epoch=38/100 train_loss_total=2.551546 train_loss_align=0.178105 train_loss_supcon=5.350280 train_loss_cls=1.838413 val_loss_total=2.593391 val_loss_align=0.183628 val_loss_supcon=5.159030 val_loss_cls=1.893859 epoch_time=7.7s
# 2026-03-30 02:02:09,354 | INFO | train | [Stage2] epoch=39/100 train_loss_total=2.555990 train_loss_align=0.178069 train_loss_supcon=5.355614 train_loss_cls=1.842360 val_loss_total=2.577374 val_loss_align=0.183357 val_loss_supcon=5.155939 val_loss_cls=1.878423 epoch_time=8.9s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:09,426 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=39 monitor_loss=2.577374)
# 2026-03-30 02:02:17,235 | INFO | train | [Stage2] epoch=40/100 train_loss_total=2.525409 train_loss_align=0.178383 train_loss_supcon=5.345433 train_loss_cls=1.812482 val_loss_total=2.564194 val_loss_align=0.183005 val_loss_supcon=5.153250 val_loss_cls=1.865864 epoch_time=7.8s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:17,302 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=40 monitor_loss=2.564194)
# 2026-03-30 02:02:25,588 | INFO | train | [Stage2] epoch=41/100 train_loss_total=2.521592 train_loss_align=0.176521 train_loss_supcon=5.349893 train_loss_cls=1.810082 val_loss_total=2.556055 val_loss_align=0.182271 val_loss_supcon=5.150813 val_loss_cls=1.858703 epoch_time=8.3s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:25,749 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=41 monitor_loss=2.556055)
# 2026-03-30 02:02:33,407 | INFO | train | [Stage2] epoch=42/100 train_loss_total=2.516406 train_loss_align=0.176167 train_loss_supcon=5.343724 train_loss_cls=1.805867 val_loss_total=2.555759 val_loss_align=0.181712 val_loss_supcon=5.151206 val_loss_cls=1.858927 epoch_time=7.7s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:33,478 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=42 monitor_loss=2.555759)
# 2026-03-30 02:02:41,582 | INFO | train | [Stage2] epoch=43/100 train_loss_total=2.517302 train_loss_align=0.175638 train_loss_supcon=5.352123 train_loss_cls=1.806452 val_loss_total=2.540359 val_loss_align=0.181758 val_loss_supcon=5.146192 val_loss_cls=1.843981 epoch_time=8.1s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:41,668 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=43 monitor_loss=2.540359)
# 2026-03-30 02:02:49,290 | INFO | train | [Stage2] epoch=44/100 train_loss_total=2.500337 train_loss_align=0.175485 train_loss_supcon=5.339189 train_loss_cls=1.790933 val_loss_total=2.532170 val_loss_align=0.181366 val_loss_supcon=5.144844 val_loss_cls=1.836320 epoch_time=7.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:02:49,322 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=44 monitor_loss=2.532170)
# 2026-03-30 02:02:57,054 | INFO | train | [Stage2] epoch=45/100 train_loss_total=2.504623 train_loss_align=0.175040 train_loss_supcon=5.347401 train_loss_cls=1.794843 val_loss_total=2.546610 val_loss_align=0.181214 val_loss_supcon=5.143931 val_loss_cls=1.851002 epoch_time=7.7s
# 2026-03-30 02:03:04,663 | INFO | train | [Stage2] epoch=46/100 train_loss_total=2.485174 train_loss_align=0.175329 train_loss_supcon=5.335874 train_loss_cls=1.776258 val_loss_total=2.523255 val_loss_align=0.180979 val_loss_supcon=5.141492 val_loss_cls=1.828127 epoch_time=7.6s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:03:04,734 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=46 monitor_loss=2.523255)
# 2026-03-30 02:03:12,696 | INFO | train | [Stage2] epoch=47/100 train_loss_total=2.488506 train_loss_align=0.175132 train_loss_supcon=5.341142 train_loss_cls=1.779259 val_loss_total=2.512852 val_loss_align=0.180471 val_loss_supcon=5.140585 val_loss_cls=1.818323 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:03:12,769 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=47 monitor_loss=2.512852)
# 2026-03-30 02:03:20,430 | INFO | train | [Stage2] epoch=48/100 train_loss_total=2.479092 train_loss_align=0.174056 train_loss_supcon=5.334275 train_loss_cls=1.771608 val_loss_total=2.516636 val_loss_align=0.180827 val_loss_supcon=5.137757 val_loss_cls=1.822034 epoch_time=7.7s
# 2026-03-30 02:03:28,411 | INFO | train | [Stage2] epoch=49/100 train_loss_total=2.472016 train_loss_align=0.174936 train_loss_supcon=5.334944 train_loss_cls=1.763585 val_loss_total=2.506902 val_loss_align=0.179642 val_loss_supcon=5.139685 val_loss_cls=1.813291 epoch_time=8.0s
# Saved checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# 2026-03-30 02:03:28,548 | INFO | train | [Stage2] new best checkpoint: new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt (epoch=49 monitor_loss=2.506902)
# 2026-03-30 02:03:36,759 | INFO | train | [Stage2] epoch=50/100 train_loss_total=2.457959 train_loss_align=0.173679 train_loss_supcon=5.330108 train_loss_cls=1.751269 val_loss_total=2.496091 val_loss_align=0.179150 val_loss_supcon=5.133507 val_loss_cls=1.803590 epoch_time=8.2s
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 1244, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 1233, in main
#     train_stage2(args, device, distributed=distributed, local_rank=local_rank)
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py", line 787, in train_stage2
#     evaluate_stage2(
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/training_eval.py", line 747, in evaluate_stage2
#     z0 = stage1.encoder(x, gait_metrics=gait_metrics)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/skeleton_model.py", line 140, in forward
#     z = g_block(z, adjacency=adjacency, edge_index=edge_index)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/graph_modules.py", line 162, in forward
#     x = x + self.ff(self.norm2(x))
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/activation.py", line 734, in forward
#     return F.gelu(input, approximate=self.approximate)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 2.81 GiB. GPU 0 has a total capacity of 23.68 GiB of which 405.44 MiB is free. Process 3535097 has 2.65 GiB memory in use. Process 3536290 has 6.70 GiB memory in use. Process 3586864 has 3.57 GiB memory in use. Including non-PyTorch memory, this process has 10.35 GiB memory in use. Of the allocated memory 6.93 GiB is allocated by PyTorch, and 3.17 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# !CUDA_VISIBLE_DEVICES=7 nohup python train.py \
  --stage 3 \
  --stage1_ckpt checkpoints_gcnn/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
  --epochs 50 \
  --lambda_motion 1.0 \
  --lambda-gait 1.0
# Out:
# ^C

# %%
# !CUDA_VISIBLE_DEVICES=6 nohup python train.py \
  --stage 3 \
  --stage1_ckpt checkpoints_gcnn/stage1_best.pt \
  --stage2_ckpt checkpoints_gcnn/stage2_best6.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 32 \
  --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
  --epochs 100 \
  --lambda_motion 1.0 \
  --lambda-gait 1.0 \
  --lambda_cls 0.1 \
  --imu_graph chain \
  --lr 3e-5

# %%
# !python probe_compare.py \
    --stage1_ckpt     /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/gcnn_stage1/stage1_best.pt \
     --stage2_ckpt     /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt \
      --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch \
    --out_dir         outputs/stage1_gcnn_stage_2_withCE
# Out:
# Loading Stage-1: /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/gcnn_stage1/stage1_best.pt
# Loading Stage-2: /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/stage1_gcnn_stage_2_withCE/stage2_best.pt
# Building dataset …
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
#   total windows: 6340
#   train=5072  val=1268
#
# Encoding training set …
# Encoding validation set …
#
#   raw  : (5072, 8640)  →  T×J×3  per window
#   skel : (5072, 737280)  →  T×J×D  per window
#   imu  : (5072, 23040)   →  T×D    per window
#
# PCA to 64 components …
#   raw  variance explained: 99.6%
#   skel variance explained: 98.6%
#   imu  variance explained: 95.8%
#
# Linear probes …
#   [skeleton] probe val acc: 0.304
#   [IMU] probe val acc: 0.168
#
#   chance = 0.071
#   skeleton probe acc = 0.304
#   IMU      probe acc = 0.168
#   → skeleton latents are more discriminative
#
# UMAP (this takes a minute) …
#   [raw]  …
# 2026-03-30 02:15:47.544673: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   [skel] …
#   [imu]  …
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:324: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#   plot saved → outputs/stage1_gcnn_stage_2_withCE/skeleton_vs_imu_umap.png
#   results → outputs/stage1_gcnn_stage_2_withCE/comparison_results.json

# %%
# !python probe_compare.py \
    --stage1_ckpt     /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/gcnn_stage1/stage1_best.pt \
     --stage2_ckpt     /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt \
      --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch \
    --out_dir         outputs/stage1_gcnn_stage_2_withCE_window
# Out:
# Loading Stage-1: /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/gcnn_stage1/stage1_best.pt
# Loading Stage-2: /home/qsw26/smartfall/gait_loss/ldm_with_loss/new_checkpoints/stage1_gcnn_stage_2_withCE_window/stage2_best.pt
# Building dataset …
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
#   total windows: 6340
#   train=5072  val=1268
#
# Encoding training set …
# Encoding validation set …
#
#   raw  : (5072, 8640)  →  T×J×3  per window
#   skel : (5072, 737280)  →  T×J×D  per window
#   imu  : (5072, 23040)   →  T×D    per window
#
# PCA to 64 components …
#   raw  variance explained: 99.6%
#   skel variance explained: 98.7%
#   imu  variance explained: 95.6%
#
# Linear probes …
#   [skeleton] probe val acc: 0.151
#   [IMU] probe val acc: 0.223
#
#   chance = 0.071
#   skeleton probe acc = 0.151
#   IMU      probe acc = 0.223
#   → IMU latents are more discriminative
#
# UMAP (this takes a minute) …
#   [raw]  …
# 2026-03-30 02:30:29.554731: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   [skel] …
#   [imu]  …
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:324: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#   plot saved → outputs/stage1_gcnn_stage_2_withCE_window/skeleton_vs_imu_umap.png
#   results → outputs/stage1_gcnn_stage_2_withCE_window/comparison_results.json

# %%
print("/home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/probe/latent_umap_before_after.png")
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/outputs/probe/latent_umap_before_after.png

# %%
# !CUDA_VISIBLE_DEVICES=4 nohup python train.py --stage 1 \
    --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
    --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/phone \
    --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/watch \
    --save_dir new_checkpoints/gcnn_stage1 \
    --batch_size 16 \
    --lambda_cls_s1 0.1 --lambda_var 0.01 \
    --encoder_type gcn \
    --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
    --epochs 100 \
    --report_dir /home/qsw26/smartfall/gait_loss/ldm_with_loss/reports/stage1 \
    --run_name stage1_gcnn
# Out:
# nohup: ignoring input and appending output to 'nohup.out'
