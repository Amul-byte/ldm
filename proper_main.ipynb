# %%
# !nohup python train.py \
  --stage 3 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --stage1_ckpt checkpoints/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --lambda-bone 0.05 --lambda-skate 0.02 --lambda-smooth 1e-4 --lambda-instab 0.1

# %%
# Stage 1
# !nohup python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --save_dir checkpoints \
  --epochs 100 \
  --batch_size 4 \
  --lr 1e-4 \
  --window 90 \
  --stride 45

# %%
# !nohup python train.py \
  --stage 2 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --stage1_ckpt checkpoints/stage1_best.pt \
  --save_dir checkpoints \
  --epochs 100 \
  --batch_size 4 \
  --lr 1e-4 \
  --window 90 \
  --stride 45

# %%
# !python generate.py \
  --stage1_ckpt checkpoints/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --stage3_ckpt checkpoints/stage3_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --batch_size 2 \
  --classify \
  --save_gif \
  --gif_dir outputs/results \
  --gif_prefix stage3_gen \
  --gif_fps 12
# Out:
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: checkpoints/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage2_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: checkpoints/stage3_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/retrain_meeting/checkpoints/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/retrain_meeting/checkpoints/stage2_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: /home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/retrain_meeting/checkpoints/stage3_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/extract_current_model_report.py:530: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", num_classes)
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/extract_current_model_report.py:563: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", num_classes)
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/extract_current_model_report.py:530: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", num_classes)
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/extract_current_model_report.py:563: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", num_classes)
# created report bundle: /home/qsw26/smartfall/gait_loss/ldm_gait_loss/outputs/current_model_report_20260314_193917

# %% [markdown]
# ## Feedbacked

# %%
# !nohup python3 train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/retrain_meeting/gait_cache_v2_9metrics \
  --save_dir outputs/retrain_meeting/checkpoints \
  --report_dir outputs/retrain_meeting/reports \
  --run_name full_stage1 \
  --epochs 100 \
  --batch_size 16 \
  --lr 1e-4 \
  --window 90 \
  --stride 45 \
  --eval_every_stage1 5
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# !nohup python3 train.py \
  --stage 2 \
  --stage1_ckpt outputs/retrain_meeting/checkpoints/stage1_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/retrain_meeting/gait_cache_v2_9metrics \
  --save_dir outputs/retrain_meeting/checkpoints \
  --report_dir outputs/retrain_meeting/reports \
  --run_name full_stage2 \
  --epochs 100 \
  --batch_size 16 \
  --lr 1e-4 \
  --window 90 \
  --stride 45\
  --eval_every_stage2 10
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# !nohup python3 train.py \
  --stage 3 \
  --stage1_ckpt outputs/retrain_meeting/checkpoints/stage1_best.pt \
  --stage2_ckpt outputs/retrain_meeting/checkpoints/stage2_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/retrain_meeting/gait_cache_v2_9metrics \
  --save_dir outputs/retrain_meeting/checkpoints \
  --report_dir outputs/retrain_meeting/reports \
  --run_name full_stage3 \
  --epochs 100 \
  --batch_size 16 \
  --lr 1e-4 \
  --window 90 \
  --stride 45 \
  --sample_steps 50 \
  --lambda_cls 0.1 \
  --lambda_motion 1.0 \
  --lambda-gait 1.0 \
  --eval_every_stage3 5
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
# !python generate.py \
  --stage1_ckpt outputs/retrain_meeting/checkpoints/stage1_best.pt \
  --stage2_ckpt outputs/retrain_meeting/checkpoints/stage2_best.pt \
  --stage3_ckpt outputs/retrain_meeting/checkpoints/stage3_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/filtered_skeleton_data \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/retrain_meeting/gait_cache_v2_9metrics \
  --batch_size 1 \
  --window 90 \
  --stride 45\
  --gait_metrics_dim 9 \
  --timesteps 1000 \
  --sample_steps 50 \
  --target_class A08 \
  --max_attempts 64 \
  --save_gif \
  --gif_dir outputs/results3 \
  --gif_prefix recent_stage3_A08 \
  --classify
# Out:
# 2026-03-14 22:22:40.945436: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/qsw26/smartfall/gait_loss/ldm_gait_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage2_best.pt
# missing keys (0): []
# unexpected keys (0): []
# Loaded checkpoint: outputs/retrain_meeting/checkpoints/stage3_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# [dataset] Skipped invalid paired sample: S49A11T01.csv
# [dataset] Skipped invalid paired sample: S51A11T01.csv
# [dataset] Skipped invalid paired sample: S52A11T03.csv
# [dataset] Skipped invalid paired sample: S52A13T01.csv
# [dataset] Skipped invalid paired sample: S52A13T03.csv
# [dataset] Skipped invalid paired sample: S52A13T04.csv
# [dataset] Skipped invalid paired sample: S52A13T05.csv
# [dataset] Skipped invalid paired sample: S52A14T01.csv
# [dataset] Skipped invalid paired sample: S52A14T02.csv
# [dataset] Skipped invalid paired sample: S52A14T03.csv
# [dataset] Skipped invalid paired sample: S53A11T01.csv
# [dataset] Skipped invalid paired sample: S53A13T05.csv
# [dataset] Skipped invalid paired sample: S53A14T01.csv
# [dataset] Skipped invalid paired sample: S54A11T04.csv
# [dataset] Skipped invalid paired sample: S54A11T05.csv
# [dataset] Skipped invalid paired sample: S54A14T04.csv
# [dataset] Skipped invalid paired sample: S54A14T05.csv
# [dataset] Skipped invalid paired sample: S56A10T03.csv
# [dataset] Skipped invalid paired sample: S60A08T01.csv
# conditioning sample class: id=7 name=A08
# target class: id=7 name=A08 | matched=True | attempts=4
# h_global shape: (1, 256)
# z0_gen shape: (1, 90, 32, 256)
# x_hat shape: (1, 90, 32, 3)
# predicted class for sample[0]: id=7 name=A08
# saved gif: outputs/results3/recent_stage3_A08_20260314_222335_idx00_A08.gif
# logits shape: (1, 14)
