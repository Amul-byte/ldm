# %%
```bash
cd /home/qsw26/smartfall/gait_loss/ldm

# Stage 1 (skeleton latent pretrain)
python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 \
  --batch_size 16 --epochs 20 --lr 1e-4 \
  --timesteps 500 --no_amp \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal

# Stage 2 (requires Stage 1 checkpoint)
python train.py \
  --stage 2 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 \
  --batch_size 32 --epochs 20 --lr 1e-4 \
  --timesteps 500 --no_amp \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal/stage1.pt \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal

# Stage 3 strict proposal (iterative reverse denoising in training; slower)
python train.py \
  --stage 3 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 \
  --batch_size 2 --epochs 20 --lr 5e-5 \
  --timesteps 500 --no_amp \
  --stage1_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal/stage1.pt \
  --stage2_ckpt /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal/stage2.pt \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal
```

Use `stage3_best.pt` from that save dir for generation.

# %%
# !python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 --stride 45 \
  --batch_size 16 --epochs 20 --lr 1e-4 \
  --timesteps 500 --no_amp \
  --save_dir /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal
# Out:
# 2026-03-01 23:51:57,743 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-01 23:51:57,743 | INFO | train | Run dir: /home/qsw26/smartfall/gait_loss/ldm/checkpoints/strict_proposal
# 2026-03-01 23:51:57,743 | INFO | train | Device: cuda
# 2026-03-01 23:51:57,743 | INFO | train | Config: stage=1 epochs=20 batch_size=16 lr=0.0001 window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# 2026-03-01 23:51:57,743 | INFO | train | Data mode: csv-folders
# 2026-03-01 23:51:57,743 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-01 23:51:57,743 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-01 23:51:57,743 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# /home/qsw26/smartfall/gait_loss/ldm/train.py:265: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-01 23:52:10,815 | INFO | train | Dataset: CSVPairedGaitDataset samples=5446 batches_per_epoch=340 drop_last=True
# Stage1 Epoch 1/20:   6%|▍     | 22/340 [00:05<01:05,  4.86it/s, loss=72931.4963]
