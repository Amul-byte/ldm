# %%
# Stage 1
python train.py --stage 1 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --save_dir checkpoints

# Stage 2
python train.py --stage 2 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --stage1_ckpt checkpoints/stage1.pt --save_dir checkpoints

# Stage 3
python train.py --stage 3 --epochs 1 --batch_size 2 --synthetic_length 8 --timesteps 50 --stage1_ckpt checkpoints/stage1.pt --stage2_ckpt checkpoints/stage2.pt --save_dir checkpoints

# Generate + classify + GIF
python generate.py \
  --stage1_ckpt checkpoints/stage1.pt \
  --stage2_ckpt checkpoints/stage2.pt \
  --timesteps 50 \
  --batch_size 2 \
  --save_gif \
  --gif_dir outputs/gifs \
  --gif_prefix gait \
  --classify

# %%
# !python train.py \
  --stage 1 \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --window 90 \
  --stride 45 \
  --batch_size 32 \
  --epochs 20
# Out:
# ========================================================================
# 3-Stage Joint-Aware Latent Diffusion Training
# ========================================================================
# stage=1 device=cuda epochs=20 batch_size=32 lr=0.0001
# window=90 stride=45 joints=32 latent_dim=256 timesteps=500
# data_mode=csv-folders
# skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# ========================================================================
# dataset=CSVPairedGaitDataset samples=5446 batches_per_epoch=170 drop_last=True
# Traceback (most recent call last):
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 299, in <module>
#     main()
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 289, in main
#     train_stage1(args, device)
#   File "/home/qsw26/smartfall/gait_loss/ldm/train.py", line 128, in train_stage1
#     out = model(x)
#           ^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/model.py", line 66, in forward
#     loss_diff = self.diffusion.predict_noise_loss(self.denoiser, z0, t, h_tokens=None, h_global=None)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/diffusion.py", line 80, in predict_noise_loss
#     pred_noise = denoiser(zt, t, sensor_tokens=h_tokens, h_tokens=h_tokens, h_global=h_global)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/skeleton_model.py", line 120, in forward
#     adjacency = build_adjacency_matrix(num_joints=self.num_joints, device=z_t.device)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qsw26/smartfall/gait_loss/ldm/diffusion_model/util.py", line -1, in build_adjacency_matrix
# KeyboardInterrupt
# ^C
