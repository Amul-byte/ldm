# %%
# !python train.py \
  --stage 2 \
  --stage1_ckpt checkpoints_gcnn/stage1_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --epochs 100
# Out:
# 2026-03-24 01:28:00.767761: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-24 01:28:04,901 | INFO | train | DDP enabled: False (world_size=1)
# 2026-03-24 01:28:04,901 | INFO | train | Run dir: checkpoints
# 2026-03-24 01:28:04,902 | INFO | train | Device: cuda
# 2026-03-24 01:28:04,902 | INFO | train | Config: stage=2 epochs=100 batch_size=16 lr=0.0001 window=90 stride=30 joints=32 latent_dim=256 timesteps=500 val_split=0.1
# 2026-03-24 01:28:04,902 | INFO | train | Data mode: csv-folders
# 2026-03-24 01:28:04,906 | INFO | train | skeleton_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton
# 2026-03-24 01:28:04,906 | INFO | train | hip_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip
# 2026-03-24 01:28:04,906 | INFO | train | wrist_folder=/home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist
# 2026-03-24 01:28:04,906 | INFO | train | gait_cache_dir=outputs/gait_cache
# 2026-03-24 01:28:04,907 | INFO | train | Gait metrics dim: 9
# 2026-03-24 01:28:04,913 | INFO | train | Gait metric names: Mean CoM Fore Aft, StDev CoM Fore Aft, Mean CoM Width, StDev CoM Width, Mean CoM Height, StDev CoM Height, Mean Walking Speed, Mean Stride Width, Mean Base of Support
# 2026-03-24 01:28:04,913 | INFO | train | IMU feature names: ax, ay, az, magnitude, pitch, roll
# 2026-03-24 01:28:04,913 | INFO | train | One-to-one mode: True
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/diffusion_model/model_loader.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# Loaded checkpoint: checkpoints_gcnn/stage1_best.pt
# missing keys (0): []
# unexpected keys (0): []
# [dataset] Skipped empty/unreadable file: S50A01T01.csv
# [dataset] Skipped empty/unreadable file: S50A01T02.csv
# [dataset] Skipped empty/unreadable file: S50A01T03.csv
# [dataset] Skipped empty/unreadable file: S50A02T04.csv
# [dataset] Skipped empty/unreadable file: S50A02T05.csv
# [dataset] Skipped empty/unreadable file: S50A05T02.csv
# [dataset] Skipped empty/unreadable file: S50A06T01.csv
# [dataset] Skipped empty/unreadable file: S50A10T05.csv
# [dataset] Skipped empty/unreadable file: S50A11T01.csv
# [dataset] Skipped empty/unreadable file: S50A11T03.csv
# [dataset] Skipped empty/unreadable file: S50A11T05.csv
# [dataset] Skipped empty/unreadable file: S50A12T03.csv
# [dataset] Skipped empty/unreadable file: S50A13T04.csv
# [dataset] Skipped empty/unreadable file: S51A13T02.csv
# [dataset] Skipped empty/unreadable file: S52A03T01.csv
# [dataset] Skipped empty/unreadable file: S52A05T03.csv
# [dataset] Skipped empty/unreadable file: S52A05T04.csv
# [dataset] Skipped empty/unreadable file: S52A05T05.csv
# [dataset] Skipped empty/unreadable file: S54A10T02.csv
# [dataset] Skipped empty/unreadable file: S56A10T02.csv
# [dataset] Skipped empty/unreadable file: S58A09T05.csv
# [dataset] Skipped empty/unreadable file: S60A02T02.csv
# [dataset] Skipped empty/unreadable file: S60A11T01.csv
# [dataset] Skipped invalid paired sample: S32A03T04.csv
# [dataset] Skipped invalid paired sample: S32A03T05.csv
# /home/qsw26/smartfall/gait_loss/ldm_with_loss/train.py:590: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# 2026-03-24 01:28:35,623 | INFO | train | Dataset: Subset samples=7066 batches_per_epoch=441 drop_last=True
# 2026-03-24 01:28:35,623 | INFO | train | Validation: samples=785 batches=50 drop_last=False
# 2026-03-24 01:29:17,667 | INFO | train | [Stage2] epoch=1/100 train_loss_align=2.177895 train_loss_gait=2.139622 val_loss_align=1.853469 epoch_time=42.0s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:29:17,811 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=1 monitor_loss=1.853469)
# 2026-03-24 01:29:57,362 | INFO | train | [Stage2] epoch=2/100 train_loss_align=1.703308 train_loss_gait=1.686407 val_loss_align=1.620060 epoch_time=39.5s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:29:57,429 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=2 monitor_loss=1.620060)
# 2026-03-24 01:30:34,295 | INFO | train | [Stage2] epoch=3/100 train_loss_align=1.458166 train_loss_gait=1.445304 val_loss_align=1.388984 epoch_time=36.9s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:30:34,493 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=3 monitor_loss=1.388984)
# 2026-03-24 01:31:12,751 | INFO | train | [Stage2] epoch=4/100 train_loss_align=1.285883 train_loss_gait=1.274880 val_loss_align=1.249206 epoch_time=38.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:31:12,838 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=4 monitor_loss=1.249206)
# 2026-03-24 01:31:48,829 | INFO | train | [Stage2] epoch=5/100 train_loss_align=1.149696 train_loss_gait=1.140301 val_loss_align=1.161321 epoch_time=36.0s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:31:49,021 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=5 monitor_loss=1.161321)
# 2026-03-24 01:32:25,099 | INFO | train | [Stage2] epoch=6/100 train_loss_align=1.030520 train_loss_gait=1.022567 val_loss_align=1.064802 epoch_time=36.1s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:32:25,208 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=6 monitor_loss=1.064802)
# 2026-03-24 01:33:00,701 | INFO | train | [Stage2] epoch=7/100 train_loss_align=0.952449 train_loss_gait=0.945182 val_loss_align=0.967739 epoch_time=35.5s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:33:00,809 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=7 monitor_loss=0.967739)
# 2026-03-24 01:33:36,963 | INFO | train | [Stage2] epoch=8/100 train_loss_align=0.865610 train_loss_gait=0.859342 val_loss_align=0.945565 epoch_time=36.2s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:33:37,059 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=8 monitor_loss=0.945565)
# 2026-03-24 01:34:16,342 | INFO | train | [Stage2] epoch=9/100 train_loss_align=0.793988 train_loss_gait=0.788233 val_loss_align=0.871199 epoch_time=39.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:34:16,463 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=9 monitor_loss=0.871199)
# 2026-03-24 01:34:55,833 | INFO | train | [Stage2] epoch=10/100 train_loss_align=0.748631 train_loss_gait=0.743378 val_loss_align=0.780745 epoch_time=39.4s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:42:34,700 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=10 monitor_loss=0.780745)
# 2026-03-24 01:43:11,064 | INFO | train | [Stage2] epoch=11/100 train_loss_align=0.686532 train_loss_gait=0.681687 val_loss_align=0.745733 epoch_time=36.4s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:43:11,146 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=11 monitor_loss=0.745733)
# 2026-03-24 01:43:48,371 | INFO | train | [Stage2] epoch=12/100 train_loss_align=0.642647 train_loss_gait=0.638472 val_loss_align=0.773113 epoch_time=37.2s
# 2026-03-24 01:44:26,374 | INFO | train | [Stage2] epoch=13/100 train_loss_align=0.603194 train_loss_gait=0.599096 val_loss_align=0.660067 epoch_time=38.0s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:44:26,521 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=13 monitor_loss=0.660067)
# 2026-03-24 01:45:03,242 | INFO | train | [Stage2] epoch=14/100 train_loss_align=0.565184 train_loss_gait=0.561324 val_loss_align=0.711423 epoch_time=36.7s
# 2026-03-24 01:45:41,392 | INFO | train | [Stage2] epoch=15/100 train_loss_align=0.542587 train_loss_gait=0.538945 val_loss_align=0.611098 epoch_time=38.1s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:45:41,651 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=15 monitor_loss=0.611098)
# 2026-03-24 01:46:21,431 | INFO | train | [Stage2] epoch=16/100 train_loss_align=0.482811 train_loss_gait=0.479381 val_loss_align=0.575812 epoch_time=39.8s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:46:21,540 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=16 monitor_loss=0.575812)
# 2026-03-24 01:47:00,881 | INFO | train | [Stage2] epoch=17/100 train_loss_align=0.472817 train_loss_gait=0.469681 val_loss_align=0.574968 epoch_time=39.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:47:01,029 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=17 monitor_loss=0.574968)
# 2026-03-24 01:47:37,336 | INFO | train | [Stage2] epoch=18/100 train_loss_align=0.440900 train_loss_gait=0.438044 val_loss_align=0.549617 epoch_time=36.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:47:37,440 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=18 monitor_loss=0.549617)
# 2026-03-24 01:48:13,264 | INFO | train | [Stage2] epoch=19/100 train_loss_align=0.415044 train_loss_gait=0.412355 val_loss_align=0.513884 epoch_time=35.8s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:48:13,444 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=19 monitor_loss=0.513884)
# 2026-03-24 01:48:49,200 | INFO | train | [Stage2] epoch=20/100 train_loss_align=0.418501 train_loss_gait=0.415784 val_loss_align=0.529921 epoch_time=35.8s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 01:56:37,652 | INFO | train | [Stage2] epoch=21/100 train_loss_align=0.381320 train_loss_gait=0.378780 val_loss_align=0.533522 epoch_time=37.7s
# 2026-03-24 01:57:17,817 | INFO | train | [Stage2] epoch=22/100 train_loss_align=0.360783 train_loss_gait=0.358417 val_loss_align=0.480897 epoch_time=40.2s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:57:18,034 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=22 monitor_loss=0.480897)
# 2026-03-24 01:57:56,806 | INFO | train | [Stage2] epoch=23/100 train_loss_align=0.337507 train_loss_gait=0.335262 val_loss_align=0.454104 epoch_time=38.8s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 01:57:56,955 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=23 monitor_loss=0.454104)
# 2026-03-24 01:58:34,163 | INFO | train | [Stage2] epoch=24/100 train_loss_align=0.328860 train_loss_gait=0.326660 val_loss_align=0.459960 epoch_time=37.2s
# 2026-03-24 01:59:14,112 | INFO | train | [Stage2] epoch=25/100 train_loss_align=0.318143 train_loss_gait=0.316090 val_loss_align=0.456052 epoch_time=39.9s
# 2026-03-24 01:59:50,811 | INFO | train | [Stage2] epoch=26/100 train_loss_align=0.304851 train_loss_gait=0.302831 val_loss_align=0.463938 epoch_time=36.7s
# 2026-03-24 02:00:27,130 | INFO | train | [Stage2] epoch=27/100 train_loss_align=0.288786 train_loss_gait=0.287011 val_loss_align=0.400903 epoch_time=36.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:00:27,246 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=27 monitor_loss=0.400903)
# 2026-03-24 02:01:06,015 | INFO | train | [Stage2] epoch=28/100 train_loss_align=0.275422 train_loss_gait=0.273588 val_loss_align=0.400662 epoch_time=38.8s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:01:06,140 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=28 monitor_loss=0.400662)
# 2026-03-24 02:01:44,390 | INFO | train | [Stage2] epoch=29/100 train_loss_align=0.284044 train_loss_gait=0.282318 val_loss_align=0.451748 epoch_time=38.2s
# 2026-03-24 02:02:29,111 | INFO | train | [Stage2] epoch=30/100 train_loss_align=0.260061 train_loss_gait=0.258407 val_loss_align=0.394361 epoch_time=44.7s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:10:01,177 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=30 monitor_loss=0.394361)
# 2026-03-24 02:10:40,704 | INFO | train | [Stage2] epoch=31/100 train_loss_align=0.259061 train_loss_gait=0.257397 val_loss_align=0.428810 epoch_time=39.5s
# 2026-03-24 02:11:20,591 | INFO | train | [Stage2] epoch=32/100 train_loss_align=0.246690 train_loss_gait=0.245092 val_loss_align=0.429810 epoch_time=39.9s
# 2026-03-24 02:11:59,955 | INFO | train | [Stage2] epoch=33/100 train_loss_align=0.227358 train_loss_gait=0.225857 val_loss_align=0.388954 epoch_time=39.4s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:12:00,085 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=33 monitor_loss=0.388954)
# 2026-03-24 02:12:40,409 | INFO | train | [Stage2] epoch=34/100 train_loss_align=0.214961 train_loss_gait=0.213576 val_loss_align=0.390492 epoch_time=40.3s
# 2026-03-24 02:13:23,480 | INFO | train | [Stage2] epoch=35/100 train_loss_align=0.220362 train_loss_gait=0.218832 val_loss_align=0.388661 epoch_time=43.1s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:13:23,683 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=35 monitor_loss=0.388661)
# 2026-03-24 02:14:07,979 | INFO | train | [Stage2] epoch=36/100 train_loss_align=0.235180 train_loss_gait=0.233734 val_loss_align=0.342841 epoch_time=44.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:14:08,206 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=36 monitor_loss=0.342841)
# 2026-03-24 02:14:50,565 | INFO | train | [Stage2] epoch=37/100 train_loss_align=0.196010 train_loss_gait=0.194644 val_loss_align=0.390726 epoch_time=42.4s
# 2026-03-24 02:15:28,745 | INFO | train | [Stage2] epoch=38/100 train_loss_align=0.202818 train_loss_gait=0.201427 val_loss_align=0.391661 epoch_time=38.2s
# 2026-03-24 02:16:08,804 | INFO | train | [Stage2] epoch=39/100 train_loss_align=0.195688 train_loss_gait=0.194478 val_loss_align=0.375727 epoch_time=40.1s
# 2026-03-24 02:16:48,379 | INFO | train | [Stage2] epoch=40/100 train_loss_align=0.205393 train_loss_gait=0.204174 val_loss_align=0.329804 epoch_time=39.6s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:24:08,745 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=40 monitor_loss=0.329804)
# 2026-03-24 02:24:47,817 | INFO | train | [Stage2] epoch=41/100 train_loss_align=0.183090 train_loss_gait=0.181841 val_loss_align=0.484300 epoch_time=39.1s
# 2026-03-24 02:25:29,078 | INFO | train | [Stage2] epoch=42/100 train_loss_align=0.187561 train_loss_gait=0.186359 val_loss_align=0.399077 epoch_time=41.3s
# 2026-03-24 02:26:11,885 | INFO | train | [Stage2] epoch=43/100 train_loss_align=0.176002 train_loss_gait=0.174834 val_loss_align=0.329899 epoch_time=42.8s
# 2026-03-24 02:26:52,891 | INFO | train | [Stage2] epoch=44/100 train_loss_align=0.171450 train_loss_gait=0.170339 val_loss_align=0.339056 epoch_time=41.0s
# 2026-03-24 02:27:32,991 | INFO | train | [Stage2] epoch=45/100 train_loss_align=0.180005 train_loss_gait=0.178910 val_loss_align=0.316725 epoch_time=40.1s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:27:33,090 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=45 monitor_loss=0.316725)
# 2026-03-24 02:28:12,716 | INFO | train | [Stage2] epoch=46/100 train_loss_align=0.145799 train_loss_gait=0.144730 val_loss_align=0.352001 epoch_time=39.6s
# 2026-03-24 02:28:54,286 | INFO | train | [Stage2] epoch=47/100 train_loss_align=0.168595 train_loss_gait=0.167492 val_loss_align=0.370345 epoch_time=41.6s
# 2026-03-24 02:29:34,920 | INFO | train | [Stage2] epoch=48/100 train_loss_align=0.167458 train_loss_gait=0.166343 val_loss_align=0.322978 epoch_time=40.6s
# 2026-03-24 02:30:18,664 | INFO | train | [Stage2] epoch=49/100 train_loss_align=0.151194 train_loss_gait=0.150180 val_loss_align=0.418851 epoch_time=43.7s
# 2026-03-24 02:31:04,276 | INFO | train | [Stage2] epoch=50/100 train_loss_align=0.153657 train_loss_gait=0.152670 val_loss_align=0.339395 epoch_time=45.6s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 02:38:53,068 | INFO | train | [Stage2] epoch=51/100 train_loss_align=0.153626 train_loss_gait=0.152553 val_loss_align=0.352072 epoch_time=39.8s
# 2026-03-24 02:39:34,500 | INFO | train | [Stage2] epoch=52/100 train_loss_align=0.140969 train_loss_gait=0.139973 val_loss_align=0.307923 epoch_time=41.4s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:39:34,593 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=52 monitor_loss=0.307923)
# 2026-03-24 02:40:13,558 | INFO | train | [Stage2] epoch=53/100 train_loss_align=0.151796 train_loss_gait=0.150776 val_loss_align=0.347739 epoch_time=39.0s
# 2026-03-24 02:40:53,006 | INFO | train | [Stage2] epoch=54/100 train_loss_align=0.144353 train_loss_gait=0.143306 val_loss_align=0.338498 epoch_time=39.4s
# 2026-03-24 02:41:37,257 | INFO | train | [Stage2] epoch=55/100 train_loss_align=0.139856 train_loss_gait=0.138869 val_loss_align=0.293597 epoch_time=44.3s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:41:37,365 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=55 monitor_loss=0.293597)
# 2026-03-24 02:42:23,134 | INFO | train | [Stage2] epoch=56/100 train_loss_align=0.136986 train_loss_gait=0.136016 val_loss_align=0.290662 epoch_time=45.8s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:42:23,195 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=56 monitor_loss=0.290662)
# 2026-03-24 02:43:05,253 | INFO | train | [Stage2] epoch=57/100 train_loss_align=0.122490 train_loss_gait=0.121601 val_loss_align=0.356447 epoch_time=42.1s
# 2026-03-24 02:43:44,630 | INFO | train | [Stage2] epoch=58/100 train_loss_align=0.131940 train_loss_gait=0.131036 val_loss_align=0.315989 epoch_time=39.4s
# 2026-03-24 02:44:25,171 | INFO | train | [Stage2] epoch=59/100 train_loss_align=0.123141 train_loss_gait=0.122236 val_loss_align=0.261968 epoch_time=40.5s
# Saved checkpoint: checkpoints/stage2_best.pt
# 2026-03-24 02:44:25,269 | INFO | train | [Stage2] new best checkpoint: checkpoints/stage2_best.pt (epoch=59 monitor_loss=0.261968)
# 2026-03-24 02:45:06,328 | INFO | train | [Stage2] epoch=60/100 train_loss_align=0.124225 train_loss_gait=0.123387 val_loss_align=0.298212 epoch_time=41.1s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 02:54:16,060 | INFO | train | [Stage2] epoch=61/100 train_loss_align=0.130467 train_loss_gait=0.129555 val_loss_align=0.313265 epoch_time=44.1s
# 2026-03-24 02:54:54,813 | INFO | train | [Stage2] epoch=62/100 train_loss_align=0.129007 train_loss_gait=0.128066 val_loss_align=0.332152 epoch_time=38.8s
# 2026-03-24 02:55:34,953 | INFO | train | [Stage2] epoch=63/100 train_loss_align=0.118504 train_loss_gait=0.117603 val_loss_align=0.294744 epoch_time=40.1s
# 2026-03-24 02:56:15,440 | INFO | train | [Stage2] epoch=64/100 train_loss_align=0.110663 train_loss_gait=0.109816 val_loss_align=0.360038 epoch_time=40.5s
# 2026-03-24 02:56:54,895 | INFO | train | [Stage2] epoch=65/100 train_loss_align=0.133388 train_loss_gait=0.132520 val_loss_align=0.310714 epoch_time=39.4s
# 2026-03-24 02:57:34,376 | INFO | train | [Stage2] epoch=66/100 train_loss_align=0.116306 train_loss_gait=0.115452 val_loss_align=0.275682 epoch_time=39.5s
# 2026-03-24 02:58:11,652 | INFO | train | [Stage2] epoch=67/100 train_loss_align=0.126922 train_loss_gait=0.126114 val_loss_align=0.390418 epoch_time=37.3s
# 2026-03-24 02:58:50,715 | INFO | train | [Stage2] epoch=68/100 train_loss_align=0.114473 train_loss_gait=0.113683 val_loss_align=0.338439 epoch_time=39.1s
# 2026-03-24 02:59:30,907 | INFO | train | [Stage2] epoch=69/100 train_loss_align=0.104550 train_loss_gait=0.103758 val_loss_align=0.321789 epoch_time=40.2s
# 2026-03-24 03:00:06,783 | INFO | train | [Stage2] epoch=70/100 train_loss_align=0.102776 train_loss_gait=0.101914 val_loss_align=0.289319 epoch_time=35.9s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 03:08:20,858 | INFO | train | [Stage2] epoch=71/100 train_loss_align=0.114173 train_loss_gait=0.113342 val_loss_align=0.302247 epoch_time=41.4s
# 2026-03-24 03:09:01,094 | INFO | train | [Stage2] epoch=72/100 train_loss_align=0.108368 train_loss_gait=0.107572 val_loss_align=0.311543 epoch_time=40.2s
# 2026-03-24 03:09:42,039 | INFO | train | [Stage2] epoch=73/100 train_loss_align=0.101797 train_loss_gait=0.101062 val_loss_align=0.295983 epoch_time=40.9s
# 2026-03-24 03:10:23,718 | INFO | train | [Stage2] epoch=74/100 train_loss_align=0.111917 train_loss_gait=0.111158 val_loss_align=0.277120 epoch_time=41.7s
# 2026-03-24 03:11:03,577 | INFO | train | [Stage2] epoch=75/100 train_loss_align=0.086166 train_loss_gait=0.085401 val_loss_align=0.285853 epoch_time=39.9s
# 2026-03-24 03:11:39,741 | INFO | train | [Stage2] epoch=76/100 train_loss_align=0.102745 train_loss_gait=0.101982 val_loss_align=0.291207 epoch_time=36.2s
# 2026-03-24 03:12:15,609 | INFO | train | [Stage2] epoch=77/100 train_loss_align=0.083255 train_loss_gait=0.082545 val_loss_align=0.262340 epoch_time=35.9s
# 2026-03-24 03:12:52,867 | INFO | train | [Stage2] epoch=78/100 train_loss_align=0.109068 train_loss_gait=0.108314 val_loss_align=0.281675 epoch_time=37.3s
# 2026-03-24 03:13:30,683 | INFO | train | [Stage2] epoch=79/100 train_loss_align=0.107382 train_loss_gait=0.106630 val_loss_align=0.303374 epoch_time=37.8s
# 2026-03-24 03:14:09,898 | INFO | train | [Stage2] epoch=80/100 train_loss_align=0.086980 train_loss_gait=0.086285 val_loss_align=0.299312 epoch_time=39.2s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 03:22:34,658 | INFO | train | [Stage2] epoch=81/100 train_loss_align=0.077292 train_loss_gait=0.076621 val_loss_align=0.311696 epoch_time=39.7s
# 2026-03-24 03:23:10,653 | INFO | train | [Stage2] epoch=82/100 train_loss_align=0.112193 train_loss_gait=0.111451 val_loss_align=0.291270 epoch_time=36.0s
# 2026-03-24 03:23:45,774 | INFO | train | [Stage2] epoch=83/100 train_loss_align=0.079026 train_loss_gait=0.078338 val_loss_align=0.306365 epoch_time=35.1s
# 2026-03-24 03:24:21,848 | INFO | train | [Stage2] epoch=84/100 train_loss_align=0.081954 train_loss_gait=0.081265 val_loss_align=0.300781 epoch_time=36.1s
# 2026-03-24 03:24:59,486 | INFO | train | [Stage2] epoch=85/100 train_loss_align=0.092249 train_loss_gait=0.091566 val_loss_align=0.285045 epoch_time=37.6s
# 2026-03-24 03:25:34,561 | INFO | train | [Stage2] epoch=86/100 train_loss_align=0.095385 train_loss_gait=0.094719 val_loss_align=0.330696 epoch_time=35.1s
# 2026-03-24 03:26:11,289 | INFO | train | [Stage2] epoch=87/100 train_loss_align=0.093594 train_loss_gait=0.092927 val_loss_align=0.298247 epoch_time=36.7s
# 2026-03-24 03:26:51,294 | INFO | train | [Stage2] epoch=88/100 train_loss_align=0.077860 train_loss_gait=0.077221 val_loss_align=0.282810 epoch_time=40.0s
# 2026-03-24 03:27:29,554 | INFO | train | [Stage2] epoch=89/100 train_loss_align=0.090643 train_loss_gait=0.089978 val_loss_align=0.313961 epoch_time=38.3s
# 2026-03-24 03:28:08,234 | INFO | train | [Stage2] epoch=90/100 train_loss_align=0.079871 train_loss_gait=0.079235 val_loss_align=0.358160 epoch_time=38.7s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# 2026-03-24 03:37:09,910 | INFO | train | [Stage2] epoch=91/100 train_loss_align=0.082853 train_loss_gait=0.082215 val_loss_align=0.334701 epoch_time=35.2s
# 2026-03-24 03:37:45,289 | INFO | train | [Stage2] epoch=92/100 train_loss_align=0.084477 train_loss_gait=0.083803 val_loss_align=0.262138 epoch_time=35.4s
# 2026-03-24 03:38:22,634 | INFO | train | [Stage2] epoch=93/100 train_loss_align=0.081306 train_loss_gait=0.080677 val_loss_align=0.296839 epoch_time=37.3s
# 2026-03-24 03:39:02,007 | INFO | train | [Stage2] epoch=94/100 train_loss_align=0.080367 train_loss_gait=0.079729 val_loss_align=0.305587 epoch_time=39.4s
# 2026-03-24 03:39:40,714 | INFO | train | [Stage2] epoch=95/100 train_loss_align=0.080990 train_loss_gait=0.080399 val_loss_align=0.365095 epoch_time=38.7s
# 2026-03-24 03:40:16,971 | INFO | train | [Stage2] epoch=96/100 train_loss_align=0.094658 train_loss_gait=0.094034 val_loss_align=0.298237 epoch_time=36.3s
# 2026-03-24 03:40:53,582 | INFO | train | [Stage2] epoch=97/100 train_loss_align=0.076813 train_loss_gait=0.076203 val_loss_align=0.351269 epoch_time=36.6s
# 2026-03-24 03:41:28,817 | INFO | train | [Stage2] epoch=98/100 train_loss_align=0.084821 train_loss_gait=0.084225 val_loss_align=0.301370 epoch_time=35.2s
# 2026-03-24 03:42:04,789 | INFO | train | [Stage2] epoch=99/100 train_loss_align=0.081094 train_loss_gait=0.080525 val_loss_align=0.302709 epoch_time=36.0s
# 2026-03-24 03:42:40,522 | INFO | train | [Stage2] epoch=100/100 train_loss_align=0.080208 train_loss_gait=0.079629 val_loss_align=0.293851 epoch_time=35.7s
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/qsw26/miniconda3/envs/smartfall_env_3.11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Saved checkpoint: checkpoints/stage2.pt
# 2026-03-24 03:50:08,951 | INFO | train | [Stage2] saved checkpoint: checkpoints/stage2.pt

# %%
# !CUDA_VISIBLE_DEVICES=7 nohup python train.py \
  --stage 3 \
  --stage1_ckpt checkpoints_gcnn/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 16 \
  --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
  --epochs 50 \
  --lambda_motion 1.0 \
  --lambda-gait 1.0
# Out:
# ^C

# %%
# !CUDA_VISIBLE_DEVICES=6 nohup python train.py \
  --stage 3 \
  --stage1_ckpt checkpoints_gcnn/stage1_best.pt \
  --stage2_ckpt checkpoints/stage2_best.pt \
  --skeleton_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/skeleton \
  --hip_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_hip \
  --wrist_folder /home/qsw26/smartfall/gait_loss/SmartFallMM-Dataset/young/accelerometer/meta_wrist \
  --gait_cache_dir outputs/gait_cache \
  --save_dir checkpoints \
  --batch_size 8 \
  --train_subjects 29,30,31,32,35,36,37,38,39,43,44,45,46,49,51,56,57,58,59,61,62 \
  --epochs 100 \
  --lambda_motion 1.0 \
  --lambda-gait 1.0 \
  --lambda_cls 0.1 \
  --imu_graph chain \
  --lr 3e-5
